# %%
### For getting coordinates for all eight different categories 
### Step 1: It will take first blastout (e.g., singel_hits_plus_strand_e1-05_soc1_blastn_bd_only_1348_50-1_epat.txt)
### Step 2: Display coordinates for each fasta file in eight different categories
#           ALl these coordinates are stored in lists pos_1,pos_2,........ Where pos_1 stores first category coordinates
### Step 3: After getting coordinates for that file, then it will count poly-A (>=9), 2 mismatches for all eight fasta 
#           categories for bd_only_1348_50-1_epat genotype 
### Step 4: Then it will count poly-A (>=5), with 0 mismatches
### Step 5: This loop will be repeated for all other 19 genotypes.
### Step 6: Check count files for all the genotpes
from pathlib import Path
import glob
import os
for filename in glob.glob('Genotypes/*.txt'): ## Getting one .txt file at one
    x = os.path.splitext(os.path.basename(filename))[0] ## Getting file name without .txt extension
    genotype_name = x
    index_1,index_2,index_3,index_4,index_5,index_6,index_7,index_8 = 0,0,0,0,0,0,0,0 ## For counting sequences in each category
    pos_1,pos_2,pos_3,pos_4,pos_5,pos_6,pos_7,pos_8 = [],[],[],[],[],[],[],[] ### To store coordinates of each category
    for i in range(1,9): ## As total categories in each file are 8, this will loop 8 times 
        data = open(filename,"r") ## Opening initial blast output file
        for line in data: ## Looping through each line
            line = line.split() ## Cnversting strings in the line into a list
            x = int(line[8]) ## Start position in read
            y = int(line[9]) ## End position in read

            ### ONLY_FP
#             if (i==1) and (x<=y)  and (x>=1) and (y<=24):
#                 pos_1.append(line[7])
#                 index_1 = index_1 + 1

            ### ONLY_UPSTREAM_UTR
            if (i==1) and (x<=y)  and (x>=25) and (y<=100): ## Get coordinates for the first category
                pos_1.append(line[7])
                index_1= index_1 + 1

            ### ONLY_BD
#             elif (i==3) and (x<=y)  and (x>=101) and (y<=107):
#                 pos_3.append(line[7])
#                 index_3= index_3 + 1

            ### ONLY_DOWNSTREAM_UTR
            elif (i==2) and (x<=y)  and (x>=108) and (y<=329): ## Get coordinates for the second category
                pos_2.append(line[7])
                index_2= index_2 + 1

            ### FP + UPSTREAM_UTR + BD + DOWNSTREAM_UTR
            elif (i==3) and (x<=y)  and (x<=24) and (108<=y<=329): ## Get coordinates for the third category
                pos_3.append(line[7])
                index_3= index_3 + 1

            ### FP + UPSTREAM _UTR+ BD
            elif (i==4) and (x<=y) and (x<=24) and (101<=y<=107): ## Get coordinates for the fourth category
                pos_4.append(line[7])
                index_4= index_4 + 1

            ### FP+ UPSTREAM_UTR
            elif (i==5) and (x<=y) and (x<=24) and (25<=y<=100): ## Get coordinates for the fifth category
                pos_5.append(line[7])
                index_5= index_5 + 1


            ### UPSTREAM_UTR + BD + DOWNSTREAM_UTR
            elif (i==6) and (x<=y) and (25<=x<=100) and (108<=y<=329): ## Get coordinates for the sixth category
                pos_6.append(line[7])
                index_6= index_6 + 1


            ### UPSTREAM_UTR + BD
            elif (i==7) and (x<=y) and (25<=x<=100) and (101<=y<=107): ## Get coordinates for the seventh category
                pos_7.append(line[7])
                index_7= index_7 + 1


            ### BD + DOWNSTREAM_UTR
            elif (i==8) and (x<=y) and (101<=x<=107) and (108<=y<=329): ## Get coordinates for the eight category
                pos_8.append(line[7])
                index_8= index_8 + 1
                
############################################################################################################
#### Once you get all the coordinates for all 8 different file, then counting starts using those coordinates
### A function to count poly-A (>=9), 2 mismatches
### If file name is singel_hits_plus_strand_e1-05_soc1_blastn_bd_only_1348_50-1_epat.txt, this genotype_name[42:]
#   give bd_only_1348_50-1_epat
## Our final count file name will be poly-a_atleast_9_bd_only_1348_50-1_epat.txt

    output_count_name_9 =  "counting_atleast_9_5/poly-a_atleast_9_" + genotype_name[42:] + ".txt"
    re = open(output_count_name_9,"a") ## Creating  poly-a_atleast_9_bd_only_1348_50-1_epat.txt
    re.write("Header" + " " + "Category" + " " + "Poly-A_Length" + " " + "Start" + " " + "End")
    re.write("\n")
    def counting(file_name,lst,file_type): # Function that takes file_name, lst and file_type as arguments
            file1 = open(file_name,"r") ## Eg: Opening Category_1.txt for genotype singel_hits_plus_strand_e1-05_soc1_blastn_bd_only_1348_50-1_epat
            flag = 0 ## Initially, setting flag to 0
            flag1 = 0 ## Initially, setting flag1 to 0
            count = 0 ## Initially, setting count to 0, this is to store length of only A's
            count1 = 0 ## Initially, setting count1 to 0, this is to store count of mismatches in poly-A. It cannot be more than 2.
            j = 0 ## Initially, setting j to 0 for looping through each coordinate in a file
            sq = '' ## For storing poly-A characters
            for line in file1: ## Eg: here we are opening Category_1.txt (in fasta folder) of singel_hits_plus_strand_e1-05_soc1_blastn_bd_only_1348_50-1_epat
                line = line.split() ## Converting each line in Category_1.txt to a list.
                if line[0][0]==">": ## IF line starts with "">
                    header = line[0] ## Store >header in header variable
                    x = lst[j] ## lst (pos_1 in function calling) is a list that contains coordinates to Category_1.txt. lst[0] will points to first corrdinate for first sequence in Category_1.txt
                    y = int(x) ## Converting coordinate type and stroring in y cariable to int for comparision
                    j = j + 1 ## Incrementing j to point to next coordinate in Category_1.txt

                else :
                    s = line[0] ## If line in Category_1.txt doesn't starts with ">"
        #             print(s)
                    ## Then the program here starts looking for any poly-A in Category_1.txt in the first sequences after specific coordinate value
                    while( y <= len(s)-1 ) : ## While loop to loop from that ccordinate to end of the character 
        #             

                        try :
            # to detect the continous A sequence even if starting index has other that a value
                            if (s[y] == s[y + 1]=="A" and count == 0) : ## If A is followed by A and count ==0
        #                         print(y)
        #                         print( '0', 's[y] =', s[y] )
                                sq = sq + s[y] ## Adding "A" to sq
                                count = count+1 ## If A is followed then count value becomes incremented by 1
        #                         print(y)
                                

                            elif ( flag !=1  and count != 0 and count1 <=2):         
                # Below  conditions are used to count other value when come in between continous sequence of (i.e 'A's)              
                                if (s[y] != 'A'):
        #                             print( '2', 's[y] =', s[y] ,'s[y+1] =', s[y + 1] , 's[y+2] =', s[y+2] ,y ) 
                                    count1 = count1+1  
                                    if count1 <3 :
                                        sq = sq + s[y]              

                                else:
        #                             print( '1', 's[y] =', s[y] ,'s[y+1] =', s[y + 1] , 's[y+2] =', s[y+2] ,y )
                                    sq = sq + s[y]
                                    count = count+1
        #                             print( '1' ,count)

                        except IndexError :
                            if s[y] =='A' and flag != 1 :
        #                         print('4')
                                sq = sq + s[y]
                                count = count+1

                        try:
                            if s[y]=="A" and count+count1 == 12 and (s[y+1:y+13] =="CGCGGCCGCGGA"):
                                sq = ''
                                count = 0
                                flag = 0
                                count1 =0
                                break
                            elif  count + count1 >=9 and ( flag == 1 or  y == len(s)-1 ):
                                start_pos = y -count-count1 ## Storing start positon in a variable
                                print(header,file_type,count+count1,start_pos,y) ## Printing all the contents
                                #############################################################
                                # Writing contents to a file
                                re.write(header) ## Sequence header
                                re.write(" ")
                                re.write(file_type) ## Category_name
                                re.write(" ")
                                re.write((str(count+count1)))  ## Poly-A length
                                re.write(" ")
                                re.write(str(start_pos)) ## Poly-A starting position
                                re.write(" ")
                                re.write(str(y)) ## Poly-A end position
                                re.write(" ")
                                re.write("\n")
                                #############################################################
                                sq = ''
                                count = 0
                                flag = 0
                                count1 =0
                                break
                        except IndexError :
                            pass


                        try :
                            if (s[y] != s[y+1] and s[y+1] != 'A' and s[y+2] != 'A'and s[y+3] !='A' and count !=0 ) or count1 > 2 :
                                if count+count1 < 9 :
                                    sq = ''
                                    flag =0
                                    count = 0
                                    count1 = 0 
                                elif count1 >2 and count+count1 >9:
                                    flag = 1
                                    count1 = count1 -1
                                else:
                                    flag = 1
                        except IndexError :
                            if count1> 2 and count+count1 >9 :
                                flag = 1
                                count1 = count1 -1 
                            elif  count+count1 > 9 :
                                flag = 1


            # intitalize all the variable for next sequence .           
                        if y == len(s)-1 : 
        #                     print("sequence",sq)
        #                     print(count ,count1)
        #                     print(flag )                
                            sq = ''
                            count = 0
                            flag = 0
                            count1 =0

                        y = y + 1  
            return 0

    main_path = 'C:/Users/johnp/Downloads/poly-a_loop/forward_strand/Genotypes/' ## main_path


    # name = main_path + genotype_name + '/fasta/Category_1.txt' ## Forward_Primer(FP) ignored category
    # file_type = "Forward_Primer(FP)"
    # counting(name,pos_1,file_type)

    name = main_path + genotype_name + '/fasta/Category_1.txt' ## Path to category_1 file
    file_type = "UPSTREAM_3'UTR" 
    counting(name,pos_1,file_type) ## Function calling to count poly-A (>=9) in category_1

    # name = main_path + "/Category_3.txt" ## BD ignored category
    # file_type = "BD"
    # counting(name,pos_3,file_type)

    name = main_path + genotype_name + "/fasta/Category_2.txt" ## Path to category_2 file
    file_type = "DOWNSTREAM_3'UTR"
    counting(name,pos_2,file_type)  ## Function calling to count poly-A (>=9) in category_2

    name = main_path + genotype_name + "/fasta/Category_3.txt" ## Path to category_3 file
    file_type = "FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR"
    counting(name,pos_3,file_type)  ## Function calling to count poly-A (>=9) in category_3

    name = main_path + genotype_name + "/fasta/Category_4.txt" ## Path to category_4 file
    file_type = "FP+UPSTREAM_3'UTR+BD"
    counting(name,pos_4,file_type)  ## Function calling to count poly-A (>=9) in category_4

    name = main_path + genotype_name + "/fasta/Category_5.txt" ## Path to category_5 file
    file_type = "FP+UPSTREAM_3'UTR"
    counting(name,pos_5,file_type)  ## Function calling to count poly-A (>=9) in category_5

    name = main_path + genotype_name + "/fasta/Category_6.txt" ## Path to category_6 file
    file_type = "UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR"
    counting(name,pos_6,file_type)  ## Function calling to count poly-A (>=9) in category_6

    name = main_path + genotype_name + "/fasta/Category_7.txt" ## Path to category_7 file
    file_type = "UPSTREAM_3'UTR+BD"
    counting(name,pos_7,file_type)  ## Function calling to count poly-A (>=9) in category_7

    name = main_path + genotype_name +"/fasta/Category_8.txt" ## Path to category_8 file
    file_type = "BD+DOWNSTREAM_3'UTR"
    counting(name,pos_8,file_type)  ## Function calling to count poly-A (>=9) in category_8
    
###############################################################################################################

#### We will use the same coordinates generated for all 8 different file, then counting starts using those coordinates
### A function to count poly-A (>=5), 0 mismatches
### If file name is singel_hits_plus_strand_e1-05_soc1_blastn_bd_only_1348_50-1_epat.txt, this genotype_name[42:]
#   give bd_only_1348_50-1_epat
## Our final count file name will be poly-a_atleast_5_bd_only_1348_50-1_epat.txt


    output_count_name_5 =  "counting_atleast_9_5/poly-a_atleast_5_" + genotype_name[42:] + ".txt" ## File to store count values
    re1 = open(output_count_name_5,"a") ## poly-a_atleast_5_bd_only_1348_50-1_epat.txt
    re1.write("Header" + " " + "Category" + " " + "Strand"  + " "+ "Poly-A_Length" + " " + "Start" + " " + "End")
    re1.write("\n")
    def counting_atleast_5(file_name,lst,file_type):  # Function that takes file_name, lst and file_type as arguments
        file2 = open(file_name,"r") ## Opening category_1 sequence file
        j = 0 ## Initialize j to 0 
        sq = '' ## Empty 
        for line in file2:
            line = line.split()
            if line[0][0]==">":
                header = line[0]
                x = lst[j]
                y = int(x)
                j = j + 1

            else:
                s = line[0]

                for i in range(len(line[0])):
                    if i==y : ## THis will ensure that you wll count after a specific coordinate
                        while( y < len(s) - 1) : ## While loop to loo through entire sequence
                            count = 1 ## Initializing count value to 1
                            start = y
                            while s[y] == s[y + 1]=="A" : 
                                sq = sq + s[y] # sq is used to store continous A's
                                y += 1 ## It will move to next character
                                count += 1 ## If A is followed by another A, then increment count value
                                if y + 1 == len(s): ## If your y (point to the positoin of a nucleotide in sequnce) is = last letter
                                    break ## then break out of the loop
                            if s[y]=="A" and count >=5: ## If poly-A = >=5
                                print(count,header,start,y+1,end = " \n") ## Printing all the contents
                                
                                #########################################
                                ## Writing all the contents to a file
                                re1.write(header) ## Sequence header
                                re1.write(" ")
                                re1.write(file_type) ## Category name
                                re1.write(" ")
                                re1.write("+") ## Indicating as positive strand
                                re1.write(" ")
                                re1.write(str(count)) ## Poly-A(>=5) length
                                re1.write(" ")
                                re1.write(str(start)) ### Start positin
                                re1.write(" ")
                                re1.write(str(y+1)) ## End position
                                re1.write(" ")
                                re1.write("\n") ## Next line
                                ############################################
                                sq = '' ## if poly=>5 is encountered, after printing it sq variable is initialized to NULL to store next poly-A
                            y = y + 1 ## If poly-A is encounter, it is counted and if another poly-A is encountered in the same sequence then we increment y
        return 0

    main_path = 'C:/Users/johnp/Downloads/poly-a_loop/forward_strand/Genotypes/' ## main_path


    # name = main_path + genotype_name + '/fasta/Category_1.txt'
    # file_type = "Forward_Primer(FP)"
    # counting_atleast_5(name,pos_1,file_type)

    name = main_path + genotype_name + '/fasta/Category_1.txt'  ## Path to category_1 file
    file_type = "UPSTREAM_3'UTR"
    counting_atleast_5(name,pos_1,file_type)  ## Function calling to count poly-A (>=5) in category_1

    # name = main_path + "/Category_3.txt"
    # file_type = "BD"
    # counting_atleast_5(name,pos_3,file_type)

    name = main_path + genotype_name + "/fasta/Category_2.txt"  ## Path to category_2 file
    file_type = "DOWNSTREAM_3'UTR"
    counting_atleast_5(name,pos_2,file_type)  ## Function calling to count poly-A (>=5) in category_2

    name = main_path + genotype_name + "/fasta/Category_3.txt"  ## Path to category_3 file
    file_type = "FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR"
    counting_atleast_5(name,pos_3,file_type)  ## Function calling to count poly-A (>=5) in category_3

    name = main_path + genotype_name + "/fasta/Category_4.txt"  ## Path to category_4 file
    file_type = "FP+UPSTREAM_3'UTR+BD"
    counting_atleast_5(name,pos_4,file_type)  ## Function calling to count poly-A (>=5) in category_4

    name = main_path + genotype_name + "/fasta/Category_5.txt"  ## Path to category_5 file
    file_type = "FP+UPSTREAM_3'UTR"
    counting_atleast_5(name,pos_5,file_type)  ## Function calling to count poly-A (>=5) in category_5

    name = main_path + genotype_name + "/fasta/Category_6.txt"  ## Path to category_6 file
    file_type = "UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR"
    counting_atleast_5(name,pos_6,file_type)  ## Function calling to count poly-A (>=5) in category_6

    name = main_path + genotype_name + "/fasta/Category_7.txt"  ## Path to category_7 file
    file_type = "UPSTREAM_3'UTR+BD"
    counting_atleast_5(name,pos_7,file_type)  ## Function calling to count poly-A (>=5) in category_7

    name = main_path + genotype_name +"/fasta/Category_8.txt"  ## Path to category_8 file
    file_type = "BD+DOWNSTREAM_3'UTR"
    counting_atleast_5(name,pos_8,file_type)  ## Function calling to count poly-A (>=5) in category_8
# Out:
# >M03997:68:000000000-G35DK:1:1101:10338:16067 DOWNSTREAM_3'UTR 9 102 111
# >M03997:68:000000000-G35DK:1:1102:23915:17669 DOWNSTREAM_3'UTR 26 43 69
# >M03997:68:000000000-G35DK:1:1102:15128:18742 DOWNSTREAM_3'UTR 10 21 31
# >M03997:68:000000000-G35DK:1:2101:7180:18097 DOWNSTREAM_3'UTR 14 21 35
# >M03997:68:000000000-G35DK:1:2104:19232:15562 DOWNSTREAM_3'UTR 12 33 45
# >M03997:68:000000000-G35DK:1:2101:6882:5657 DOWNSTREAM_3'UTR 10 60 70
# >M03997:68:000000000-G35DK:1:2104:12753:2634 DOWNSTREAM_3'UTR 21 35 56
# >M03997:68:000000000-G35DK:1:1102:11081:24951 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 20 130 150
# >M03997:68:000000000-G35DK:1:2102:13067:28713 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 13 218 231
# >M03997:68:000000000-G35DK:1:1103:16158:4135 FP+UPSTREAM_3'UTR 24 22 46
# >M03997:68:000000000-G35DK:1:1101:12601:16513 FP+UPSTREAM_3'UTR 16 46 62
# >M03997:68:000000000-G35DK:1:2104:20172:24420 FP+UPSTREAM_3'UTR 26 28 54
# >M03997:68:000000000-G35DK:1:1101:24101:6675 FP+UPSTREAM_3'UTR 16 26 42
# >M03997:68:000000000-G35DK:1:1101:20394:13198 FP+UPSTREAM_3'UTR 20 21 41
# >M03997:68:000000000-G35DK:1:1102:23814:23429 FP+UPSTREAM_3'UTR 14 26 40
# >M03997:68:000000000-G35DK:1:1101:11461:27522 FP+UPSTREAM_3'UTR 16 26 42
# >M03997:68:000000000-G35DK:1:2101:26628:14320 FP+UPSTREAM_3'UTR 9 32 41
# >M03997:68:000000000-G35DK:1:2103:19267:14147 FP+UPSTREAM_3'UTR 9 31 40
# >M03997:68:000000000-G35DK:1:2102:20377:21569 FP+UPSTREAM_3'UTR 15 22 37
# >M03997:68:000000000-G35DK:1:2101:25615:6144 FP+UPSTREAM_3'UTR 12 28 40
# >M03997:68:000000000-G35DK:1:2102:5106:20164 FP+UPSTREAM_3'UTR 28 34 62
# >M03997:68:000000000-G35DK:1:1104:13051:12981 FP+UPSTREAM_3'UTR 25 79 104
# >M03997:68:000000000-G35DK:1:1102:8252:20389 FP+UPSTREAM_3'UTR 29 72 101
# >M03997:68:000000000-G35DK:1:1101:22344:15992 FP+UPSTREAM_3'UTR 11 27 38
# >M03997:68:000000000-G35DK:1:1104:22349:15897 FP+UPSTREAM_3'UTR 11 24 35
# >M03997:68:000000000-G35DK:1:1101:27339:16600 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 17 82 99
# >M03997:68:000000000-G35DK:1:1103:26434:14711 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 11 73 84
# >M03997:68:000000000-G35DK:1:2103:25322:10036 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 11 92 103
# >M03997:68:000000000-G35DK:1:2101:12662:12738 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 14 51 65
# >M03997:68:000000000-G35DK:1:2103:12115:23719 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 79 98
# >M03997:68:000000000-G35DK:1:2102:20500:19510 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 14 79 93
# >M03997:68:000000000-G35DK:1:1102:14259:18961 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 11 21 32
# >M03997:68:000000000-G35DK:1:2103:15876:7930 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 13 97 110
# >M03997:68:000000000-G35DK:1:2103:20782:12532 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 18 30 48
# >M03997:68:000000000-G35DK:1:1104:13157:8815 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 98 117
# >M03997:68:000000000-G35DK:1:2101:26051:16596 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 20 76 96
# >M03997:68:000000000-G35DK:1:1102:11220:18723 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 15 59 74
# >M03997:68:000000000-G35DK:1:2103:21595:15988 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 97 116
# >M03997:68:000000000-G35DK:1:2104:22321:12509 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 22 80 102
# >M03997:68:000000000-G35DK:1:1101:9527:6439 BD+DOWNSTREAM_3'UTR 9 100 109
# 5 >M03997:68:000000000-G35DK:1:1101:10338:16067 87 92
# 6 >M03997:68:000000000-G35DK:1:1101:10338:16067 102 108
# 16 >M03997:68:000000000-G35DK:1:1101:10338:16067 160 176
# 26 >M03997:68:000000000-G35DK:1:1102:23915:17669 43 69
# 10 >M03997:68:000000000-G35DK:1:1102:15128:18742 22 32
# 14 >M03997:68:000000000-G35DK:1:2101:7180:18097 21 35
# 13 >M03997:68:000000000-G35DK:1:2101:7180:18097 107 120
# 12 >M03997:68:000000000-G35DK:1:2104:19232:15562 34 46
# 10 >M03997:68:000000000-G35DK:1:2101:6882:5657 61 71
# 6 >M03997:68:000000000-G35DK:1:2104:12753:2634 35 41
# 14 >M03997:68:000000000-G35DK:1:2104:12753:2634 42 56
# 12 >M03997:68:000000000-G35DK:1:2104:12753:2634 90 102
# 8 >M03997:68:000000000-G35DK:1:2104:12753:2634 135 143
# 6 >M03997:68:000000000-G35DK:1:2104:12753:2634 152 158
# 5 >M03997:68:000000000-G35DK:1:2104:12753:2634 255 260
# 6 >M03997:68:000000000-G35DK:1:1103:14665:13367 32 38
# 20 >M03997:68:000000000-G35DK:1:1102:11081:24951 130 150
# 10 >M03997:68:000000000-G35DK:1:2102:13067:28713 217 227
# 24 >M03997:68:000000000-G35DK:1:1103:16158:4135 23 47
# 5 >M03997:68:000000000-G35DK:1:2103:17706:9539 66 71
# 13 >M03997:68:000000000-G35DK:1:1101:12601:16513 49 62
# 26 >M03997:68:000000000-G35DK:1:2104:20172:24420 28 54
# 17 >M03997:68:000000000-G35DK:1:2104:20172:24420 92 109
# 11 >M03997:68:000000000-G35DK:1:2104:20172:24420 131 142
# 6 >M03997:68:000000000-G35DK:1:2104:20172:24420 206 212
# 16 >M03997:68:000000000-G35DK:1:1101:24101:6675 26 42
# 20 >M03997:68:000000000-G35DK:1:1101:20394:13198 21 41
# 9 >M03997:68:000000000-G35DK:1:1101:20394:13198 80 89
# 14 >M03997:68:000000000-G35DK:1:1102:23814:23429 26 40
# 15 >M03997:68:000000000-G35DK:1:1102:23814:23429 119 134
# 16 >M03997:68:000000000-G35DK:1:1101:11461:27522 26 42
# 15 >M03997:68:000000000-G35DK:1:2102:20377:21569 22 37
# 12 >M03997:68:000000000-G35DK:1:2101:25615:6144 28 40
# 28 >M03997:68:000000000-G35DK:1:2102:5106:20164 34 62
# 6 >M03997:68:000000000-G35DK:1:2102:5106:20164 158 164
# 25 >M03997:68:000000000-G35DK:1:1104:13051:12981 79 104
# 8 >M03997:68:000000000-G35DK:1:1104:13051:12981 282 290
# 10 >M03997:68:000000000-G35DK:1:1104:13051:12981 291 301
# 25 >M03997:68:000000000-G35DK:1:1102:8252:20389 75 100
# 6 >M03997:68:000000000-G35DK:1:1102:8252:20389 182 188
# 17 >M03997:68:000000000-G35DK:1:1101:27339:16600 82 99
# 6 >M03997:68:000000000-G35DK:1:1101:10423:11277 67 73
# 11 >M03997:68:000000000-G35DK:1:1103:26434:14711 73 84
# 11 >M03997:68:000000000-G35DK:1:2103:25322:10036 92 103
# 14 >M03997:68:000000000-G35DK:1:2101:12662:12738 51 65
# 14 >M03997:68:000000000-G35DK:1:2101:12662:12738 140 154
# 19 >M03997:68:000000000-G35DK:1:2103:12115:23719 80 99
# 12 >M03997:68:000000000-G35DK:1:2102:13995:28529 65 77
# 14 >M03997:68:000000000-G35DK:1:2102:20500:19510 79 93
# 5 >M03997:68:000000000-G35DK:1:2102:20500:19510 115 120
# 5 >M03997:68:000000000-G35DK:1:2102:20500:19510 170 175
# 6 >M03997:68:000000000-G35DK:1:2102:20500:19510 176 182
# 11 >M03997:68:000000000-G35DK:1:1102:14259:18961 21 32
# 13 >M03997:68:000000000-G35DK:1:2103:15876:7930 97 110
# 15 >M03997:68:000000000-G35DK:1:2103:15876:7930 189 204
# 18 >M03997:68:000000000-G35DK:1:2103:20782:12532 30 48
# 8 >M03997:68:000000000-G35DK:1:2103:20782:12532 86 94
# 13 >M03997:68:000000000-G35DK:1:2103:20782:12532 116 129
# 19 >M03997:68:000000000-G35DK:1:1104:13157:8815 98 117
# 5 >M03997:68:000000000-G35DK:1:1104:13157:8815 207 212
# 5 >M03997:68:000000000-G35DK:1:1104:13157:8815 272 277
# 20 >M03997:68:000000000-G35DK:1:2101:26051:16596 76 96
# 5 >M03997:68:000000000-G35DK:1:2101:26051:16596 118 123
# 8 >M03997:68:000000000-G35DK:1:2101:26051:16596 177 185
# 15 >M03997:68:000000000-G35DK:1:1102:11220:18723 59 74
# 5 >M03997:68:000000000-G35DK:1:2104:14711:17404 129 134
# 19 >M03997:68:000000000-G35DK:1:2103:21595:15988 97 116
# 22 >M03997:68:000000000-G35DK:1:2104:22321:12509 80 102
# 6 >M03997:68:000000000-G35DK:1:2104:22321:12509 177 183
# 5 >M03997:68:000000000-G35DK:1:1101:9527:6439 104 109
# 8 >M03997:68:000000000-G35DK:1:1101:9527:6439 152 160
# 5 >M03997:68:000000000-G35DK:1:1101:9527:6439 204 209
# 6 >M03997:68:000000000-G35DK:1:1104:23441:16909 49 55
# >M03997:68:000000000-G35DK:1:1102:3618:21041 UPSTREAM_3'UTR 14 111 125
# >M03997:68:000000000-G35DK:1:2102:21500:22217 DOWNSTREAM_3'UTR 28 26 54
# >M03997:68:000000000-G35DK:1:1103:20182:16975 DOWNSTREAM_3'UTR 25 51 76
# >M03997:68:000000000-G35DK:1:2103:12462:20006 DOWNSTREAM_3'UTR 15 33 48
# >M03997:68:000000000-G35DK:1:2103:20528:18773 DOWNSTREAM_3'UTR 41 27 68
# >M03997:68:000000000-G35DK:1:1103:19619:26485 DOWNSTREAM_3'UTR 16 37 53
# >M03997:68:000000000-G35DK:1:2101:13966:8998 DOWNSTREAM_3'UTR 15 42 57
# >M03997:68:000000000-G35DK:1:1102:13268:21244 DOWNSTREAM_3'UTR 16 27 43
# >M03997:68:000000000-G35DK:1:1101:7150:15282 DOWNSTREAM_3'UTR 18 38 56
# >M03997:68:000000000-G35DK:1:1103:8582:16649 DOWNSTREAM_3'UTR 28 51 79
# >M03997:68:000000000-G35DK:1:1102:7982:19509 DOWNSTREAM_3'UTR 9 21 30
# >M03997:68:000000000-G35DK:1:1101:11418:9855 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 16 197 213
# >M03997:68:000000000-G35DK:1:2102:13545:13267 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 21 109 130
# >M03997:68:000000000-G35DK:1:2104:28758:12404 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 12 158 170
# >M03997:68:000000000-G35DK:1:1102:20652:12829 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 18 108 126
# >M03997:68:000000000-G35DK:1:1103:18514:18284 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 22 106 128
# >M03997:68:000000000-G35DK:1:1103:20899:16952 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 21 146 167
# >M03997:68:000000000-G35DK:1:1101:10645:2535 FP+UPSTREAM_3'UTR+BD 12 160 172
# >M03997:68:000000000-G35DK:1:2101:19562:11822 FP+UPSTREAM_3'UTR 9 78 87
# >M03997:68:000000000-G35DK:1:1104:7080:12255 FP+UPSTREAM_3'UTR 27 79 106
# >M03997:68:000000000-G35DK:1:1104:25897:14777 FP+UPSTREAM_3'UTR 29 63 92
# >M03997:68:000000000-G35DK:1:2104:9830:14631 FP+UPSTREAM_3'UTR 9 21 30
# >M03997:68:000000000-G35DK:1:1101:11771:17518 FP+UPSTREAM_3'UTR 19 141 160
# >M03997:68:000000000-G35DK:1:1102:25010:8677 FP+UPSTREAM_3'UTR 11 26 37
# >M03997:68:000000000-G35DK:1:2102:11497:7770 FP+UPSTREAM_3'UTR 34 26 60
# >M03997:68:000000000-G35DK:1:1104:10538:23351 FP+UPSTREAM_3'UTR 14 20 34
# >M03997:68:000000000-G35DK:1:1102:8193:13041 FP+UPSTREAM_3'UTR 13 25 38
# >M03997:68:000000000-G35DK:1:1103:9199:24670 FP+UPSTREAM_3'UTR 15 42 57
# >M03997:68:000000000-G35DK:1:1101:10909:2885 FP+UPSTREAM_3'UTR 11 24 35
# >M03997:68:000000000-G35DK:1:2101:19965:13118 FP+UPSTREAM_3'UTR 14 42 56
# >M03997:68:000000000-G35DK:1:1101:27120:9688 FP+UPSTREAM_3'UTR 9 27 36
# >M03997:68:000000000-G35DK:1:2102:9667:13638 FP+UPSTREAM_3'UTR 16 79 95
# >M03997:68:000000000-G35DK:1:1101:10036:9962 FP+UPSTREAM_3'UTR 10 85 95
# >M03997:68:000000000-G35DK:1:2102:16041:3120 FP+UPSTREAM_3'UTR 9 28 37
# >M03997:68:000000000-G35DK:1:2102:24639:17653 FP+UPSTREAM_3'UTR 36 152 188
# >M03997:68:000000000-G35DK:1:1102:27908:21482 FP+UPSTREAM_3'UTR 9 31 40
# >M03997:68:000000000-G35DK:1:1101:24265:18248 FP+UPSTREAM_3'UTR 11 26 37
# >M03997:68:000000000-G35DK:1:2101:14334:15421 FP+UPSTREAM_3'UTR 12 49 61
# >M03997:68:000000000-G35DK:1:1104:28021:19338 FP+UPSTREAM_3'UTR 17 26 43
# >M03997:68:000000000-G35DK:1:2104:10683:20041 FP+UPSTREAM_3'UTR 20 28 48
# >M03997:68:000000000-G35DK:1:2102:13800:27499 FP+UPSTREAM_3'UTR 12 26 38
# >M03997:68:000000000-G35DK:1:1101:7913:26608 FP+UPSTREAM_3'UTR 9 20 29
# >M03997:68:000000000-G35DK:1:1104:26032:22705 FP+UPSTREAM_3'UTR 9 31 40
# >M03997:68:000000000-G35DK:1:2103:21871:26261 FP+UPSTREAM_3'UTR 30 26 56
# >M03997:68:000000000-G35DK:1:1103:29127:15269 FP+UPSTREAM_3'UTR 9 19 28
# >M03997:68:000000000-G35DK:1:2102:9892:27030 FP+UPSTREAM_3'UTR 18 20 38
# >M03997:68:000000000-G35DK:1:2101:7655:13700 FP+UPSTREAM_3'UTR 12 25 37
# >M03997:68:000000000-G35DK:1:1102:18508:12782 FP+UPSTREAM_3'UTR 22 55 77
# >M03997:68:000000000-G35DK:1:1104:23597:15937 FP+UPSTREAM_3'UTR 9 30 39
# >M03997:68:000000000-G35DK:1:1101:14554:13689 FP+UPSTREAM_3'UTR 17 68 85
# >M03997:68:000000000-G35DK:1:2101:6434:7429 FP+UPSTREAM_3'UTR 9 31 40
# >M03997:68:000000000-G35DK:1:1104:14414:14808 FP+UPSTREAM_3'UTR 9 30 39
# >M03997:68:000000000-G35DK:1:2102:5925:21999 FP+UPSTREAM_3'UTR 12 144 156
# >M03997:68:000000000-G35DK:1:1103:27136:16955 FP+UPSTREAM_3'UTR 15 23 38
# >M03997:68:000000000-G35DK:1:1103:9828:13666 FP+UPSTREAM_3'UTR 26 26 52
# >M03997:68:000000000-G35DK:1:2103:15292:5116 FP+UPSTREAM_3'UTR 11 24 35
# >M03997:68:000000000-G35DK:1:2103:19066:17425 FP+UPSTREAM_3'UTR 27 21 48
# >M03997:68:000000000-G35DK:1:2104:22247:13040 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 65 84
# >M03997:68:000000000-G35DK:1:1103:24193:19562 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 104 123
# >M03997:68:000000000-G35DK:1:2103:22025:14490 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 26 73 99
# >M03997:68:000000000-G35DK:1:1103:23188:25252 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 26 110 136
# >M03997:68:000000000-G35DK:1:2103:14159:15019 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 9 81 90
# >M03997:68:000000000-G35DK:1:1102:7095:7703 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 77 96
# >M03997:68:000000000-G35DK:1:1104:23079:16140 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 39 59 98
# >M03997:68:000000000-G35DK:1:1103:9389:13380 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 117 136
# >M03997:68:000000000-G35DK:1:1102:21276:15507 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 14 192 206
# >M03997:68:000000000-G35DK:1:2104:11978:9296 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 13 101 114
# >M03997:68:000000000-G35DK:1:2102:23908:7104 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 14 92 106
# >M03997:68:000000000-G35DK:1:2102:6085:24072 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 13 74 87
# >M03997:68:000000000-G35DK:1:1102:26051:22238 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 16 45 61
# >M03997:68:000000000-G35DK:1:2103:9078:3843 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 9 117 126
# >M03997:68:000000000-G35DK:1:1104:15316:13338 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 21 58 79
# >M03997:68:000000000-G35DK:1:2102:14197:11521 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 9 79 88
# >M03997:68:000000000-G35DK:1:1101:21863:6125 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 12 79 91
# 11 >M03997:68:000000000-G35DK:1:1102:3618:21041 110 121
# 5 >M03997:68:000000000-G35DK:1:1102:3618:21041 130 135
# 6 >M03997:68:000000000-G35DK:1:1102:3618:21041 205 211
# 5 >M03997:68:000000000-G35DK:1:1104:19393:21217 64 69
# 28 >M03997:68:000000000-G35DK:1:2102:21500:22217 26 54
# 6 >M03997:68:000000000-G35DK:1:2102:21500:22217 95 101
# 6 >M03997:68:000000000-G35DK:1:2102:21500:22217 137 143
# 6 >M03997:68:000000000-G35DK:1:2102:21500:22217 155 161
# 6 >M03997:68:000000000-G35DK:1:2102:21500:22217 225 231
# 5 >M03997:68:000000000-G35DK:1:2102:21500:22217 263 268
# 25 >M03997:68:000000000-G35DK:1:1103:20182:16975 51 76
# 7 >M03997:68:000000000-G35DK:1:1103:20182:16975 99 106
# 15 >M03997:68:000000000-G35DK:1:2103:12462:20006 33 48
# 15 >M03997:68:000000000-G35DK:1:2103:12462:20006 114 129
# 9 >M03997:68:000000000-G35DK:1:2103:20528:18773 27 36
# 15 >M03997:68:000000000-G35DK:1:2103:20528:18773 37 52
# 15 >M03997:68:000000000-G35DK:1:2103:20528:18773 53 68
# 8 >M03997:68:000000000-G35DK:1:2103:20528:18773 90 98
# 10 >M03997:68:000000000-G35DK:1:2103:20528:18773 146 156
# 7 >M03997:68:000000000-G35DK:1:2103:20528:18773 263 270
# 16 >M03997:68:000000000-G35DK:1:1103:19619:26485 37 53
# 11 >M03997:68:000000000-G35DK:1:1103:19619:26485 122 133
# 15 >M03997:68:000000000-G35DK:1:2101:13966:8998 42 57
# 10 >M03997:68:000000000-G35DK:1:2101:13966:8998 134 144
# 16 >M03997:68:000000000-G35DK:1:1102:13268:21244 27 43
# 18 >M03997:68:000000000-G35DK:1:1101:7150:15282 38 56
# 12 >M03997:68:000000000-G35DK:1:1101:7150:15282 128 140
# 28 >M03997:68:000000000-G35DK:1:1103:8582:16649 51 79
# 15 >M03997:68:000000000-G35DK:1:1103:8582:16649 97 112
# 8 >M03997:68:000000000-G35DK:1:1103:8582:16649 113 121
# 11 >M03997:68:000000000-G35DK:1:1103:8582:16649 155 166
# 5 >M03997:68:000000000-G35DK:1:1103:8582:16649 264 269
# 5 >M03997:68:000000000-G35DK:1:1103:8582:16649 277 282
# 9 >M03997:68:000000000-G35DK:1:1103:8582:16649 283 292
# 5 >M03997:68:000000000-G35DK:1:1102:7982:19509 22 27
# 13 >M03997:68:000000000-G35DK:1:1101:11418:9855 196 209
# 5 >M03997:68:000000000-G35DK:1:2101:24213:6406 140 145
# 21 >M03997:68:000000000-G35DK:1:2102:13545:13267 109 130
# 6 >M03997:68:000000000-G35DK:1:2102:13545:13267 208 214
# 12 >M03997:68:000000000-G35DK:1:2104:28758:12404 158 170
# 18 >M03997:68:000000000-G35DK:1:1102:20652:12829 108 126
# 22 >M03997:68:000000000-G35DK:1:1103:18514:18284 106 128
# 21 >M03997:68:000000000-G35DK:1:1103:20899:16952 146 167
# 12 >M03997:68:000000000-G35DK:1:1101:10645:2535 160 172
# 13 >M03997:68:000000000-G35DK:1:2101:19562:11822 96 109
# 24 >M03997:68:000000000-G35DK:1:1104:7080:12255 79 103
# 12 >M03997:68:000000000-G35DK:1:1104:7080:12255 178 190
# 6 >M03997:68:000000000-G35DK:1:1104:7080:12255 191 197
# 6 >M03997:68:000000000-G35DK:1:1104:7080:12255 261 267
# 29 >M03997:68:000000000-G35DK:1:1104:25897:14777 63 92
# 5 >M03997:68:000000000-G35DK:1:1104:25897:14777 131 136
# 7 >M03997:68:000000000-G35DK:1:1104:25897:14777 172 179
# 16 >M03997:68:000000000-G35DK:1:1101:11771:17518 144 160
# 34 >M03997:68:000000000-G35DK:1:2102:11497:7770 26 60
# 14 >M03997:68:000000000-G35DK:1:1104:10538:23351 20 34
# 13 >M03997:68:000000000-G35DK:1:1102:8193:13041 25 38
# 15 >M03997:68:000000000-G35DK:1:1103:9199:24670 42 57
# 11 >M03997:68:000000000-G35DK:1:2101:19965:13118 45 56
# 16 >M03997:68:000000000-G35DK:1:2102:9667:13638 79 95
# 6 >M03997:68:000000000-G35DK:1:1101:10036:9962 90 96
# 5 >M03997:68:000000000-G35DK:1:2102:24639:17653 66 71
# 34 >M03997:68:000000000-G35DK:1:2102:24639:17653 152 186
# 5 >M03997:68:000000000-G35DK:1:2102:24639:17653 206 211
# 23 >M03997:68:000000000-G35DK:1:1102:27908:21482 52 75
# 5 >M03997:68:000000000-G35DK:1:1102:27908:21482 95 100
# 5 >M03997:68:000000000-G35DK:1:1102:27908:21482 114 119
# 13 >M03997:68:000000000-G35DK:1:1102:27908:21482 151 164
# 6 >M03997:68:000000000-G35DK:1:1102:27908:21482 222 228
# 5 >M03997:68:000000000-G35DK:1:1102:27908:21482 265 270
# 18 >M03997:68:000000000-G35DK:1:1101:24265:18248 53 71
# 13 >M03997:68:000000000-G35DK:1:1101:24265:18248 148 161
# 12 >M03997:68:000000000-G35DK:1:2101:14334:15421 49 61
# 6 >M03997:68:000000000-G35DK:1:1103:21947:6082 78 84
# 17 >M03997:68:000000000-G35DK:1:1104:28021:19338 26 43
# 5 >M03997:68:000000000-G35DK:1:1104:28021:19338 120 125
# 5 >M03997:68:000000000-G35DK:1:1104:28021:19338 175 180
# 20 >M03997:68:000000000-G35DK:1:2104:10683:20041 28 48
# 11 >M03997:68:000000000-G35DK:1:2104:10683:20041 125 136
# 12 >M03997:68:000000000-G35DK:1:2102:13800:27499 26 38
# 5 >M03997:68:000000000-G35DK:1:2102:9882:12703 46 51
# 17 >M03997:68:000000000-G35DK:1:1104:26032:22705 51 68
# 11 >M03997:68:000000000-G35DK:1:1104:26032:22705 147 158
# 14 >M03997:68:000000000-G35DK:1:2103:21871:26261 26 40
# 15 >M03997:68:000000000-G35DK:1:2103:21871:26261 41 56
# 9 >M03997:68:000000000-G35DK:1:2103:21871:26261 136 145
# 18 >M03997:68:000000000-G35DK:1:2102:9892:27030 20 38
# 12 >M03997:68:000000000-G35DK:1:2101:7655:13700 26 38
# 22 >M03997:68:000000000-G35DK:1:1102:18508:12782 55 77
# 9 >M03997:68:000000000-G35DK:1:1102:18508:12782 97 106
# 7 >M03997:68:000000000-G35DK:1:1102:18508:12782 158 165
# 17 >M03997:68:000000000-G35DK:1:1101:14554:13689 68 85
# 18 >M03997:68:000000000-G35DK:1:2101:6434:7429 63 81
# 5 >M03997:68:000000000-G35DK:1:2101:6434:7429 163 168
# 5 >M03997:68:000000000-G35DK:1:2102:5925:21999 89 94
# 12 >M03997:68:000000000-G35DK:1:2102:5925:21999 144 156
# 15 >M03997:68:000000000-G35DK:1:1103:27136:16955 23 38
# 26 >M03997:68:000000000-G35DK:1:1103:9828:13666 26 52
# 7 >M03997:68:000000000-G35DK:1:1103:9828:13666 84 91
# 8 >M03997:68:000000000-G35DK:1:1103:9828:13666 126 134
# 6 >M03997:68:000000000-G35DK:1:1103:9828:13666 141 147
# 5 >M03997:68:000000000-G35DK:1:1103:9828:13666 150 155
# 27 >M03997:68:000000000-G35DK:1:2103:19066:17425 21 48
# 11 >M03997:68:000000000-G35DK:1:2103:19066:17425 85 96
# 15 >M03997:68:000000000-G35DK:1:2103:19066:17425 115 130
# 11 >M03997:68:000000000-G35DK:1:2103:19066:17425 132 143
# 19 >M03997:68:000000000-G35DK:1:2104:22247:13040 65 84
# 7 >M03997:68:000000000-G35DK:1:2104:22247:13040 165 172
# 6 >M03997:68:000000000-G35DK:1:2104:22247:13040 173 179
# 19 >M03997:68:000000000-G35DK:1:1103:24193:19562 104 123
# 26 >M03997:68:000000000-G35DK:1:2103:22025:14490 73 99
# 5 >M03997:68:000000000-G35DK:1:2103:22025:14490 117 122
# 8 >M03997:68:000000000-G35DK:1:2103:22025:14490 174 182
# 5 >M03997:68:000000000-G35DK:1:2103:22025:14490 183 188
# 26 >M03997:68:000000000-G35DK:1:1103:23188:25252 110 136
# 6 >M03997:68:000000000-G35DK:1:1103:23188:25252 206 212
# 9 >M03997:68:000000000-G35DK:1:2103:14159:15019 82 91
# 19 >M03997:68:000000000-G35DK:1:1102:7095:7703 78 97
# 39 >M03997:68:000000000-G35DK:1:1104:23079:16140 59 98
# 24 >M03997:68:000000000-G35DK:1:1104:23079:16140 101 125
# 6 >M03997:68:000000000-G35DK:1:1104:23079:16140 133 139
# 5 >M03997:68:000000000-G35DK:1:1104:23079:16140 179 184
# 5 >M03997:68:000000000-G35DK:1:1104:23079:16140 295 300
# 5 >M03997:68:000000000-G35DK:1:2102:19202:20415 61 66
# 19 >M03997:68:000000000-G35DK:1:1103:9389:13380 117 136
# 6 >M03997:68:000000000-G35DK:1:1101:16304:6349 75 81
# 5 >M03997:68:000000000-G35DK:1:1103:14622:28716 117 122
# 6 >M03997:68:000000000-G35DK:1:1102:21276:15507 117 123
# 11 >M03997:68:000000000-G35DK:1:1102:21276:15507 191 202
# 5 >M03997:68:000000000-G35DK:1:1102:21276:15507 206 211
# 9 >M03997:68:000000000-G35DK:1:1102:21276:15507 214 223
# 13 >M03997:68:000000000-G35DK:1:2104:11978:9296 101 114
# 6 >M03997:68:000000000-G35DK:1:2104:11978:9296 148 154
# 8 >M03997:68:000000000-G35DK:1:2104:11978:9296 192 200
# 14 >M03997:68:000000000-G35DK:1:2102:23908:7104 93 107
# 13 >M03997:68:000000000-G35DK:1:2102:6085:24072 75 88
# 5 >M03997:68:000000000-G35DK:1:2102:26013:12274 119 124
# 8 >M03997:68:000000000-G35DK:1:2104:8620:12681 90 98
# 16 >M03997:68:000000000-G35DK:1:1102:26051:22238 45 61
# 9 >M03997:68:000000000-G35DK:1:2103:9078:3843 118 127
# 21 >M03997:68:000000000-G35DK:1:1104:15316:13338 58 79
# 9 >M03997:68:000000000-G35DK:1:1104:15316:13338 99 108
# 5 >M03997:68:000000000-G35DK:1:1104:15316:13338 164 169
# 9 >M03997:68:000000000-G35DK:1:2102:14197:11521 80 89
# 12 >M03997:68:000000000-G35DK:1:1101:21863:6125 79 91
# >M03997:68:000000000-G35DK:1:1103:22878:4987 DOWNSTREAM_3'UTR 11 147 158
# >M03997:68:000000000-G35DK:1:1101:23951:17954 DOWNSTREAM_3'UTR 9 32 41
# >M03997:68:000000000-G35DK:1:1104:18371:21267 DOWNSTREAM_3'UTR 32 45 77
# >M03997:68:000000000-G35DK:1:1101:21993:26823 DOWNSTREAM_3'UTR 14 70 84
# >M03997:68:000000000-G35DK:1:2101:6155:21319 DOWNSTREAM_3'UTR 9 32 41
# >M03997:68:000000000-G35DK:1:1101:20334:7334 DOWNSTREAM_3'UTR 21 43 64
# >M03997:68:000000000-G35DK:1:2103:12471:4180 DOWNSTREAM_3'UTR 22 41 63
# >M03997:68:000000000-G35DK:1:2104:27709:12302 DOWNSTREAM_3'UTR 21 46 67
# >M03997:68:000000000-G35DK:1:1104:22582:12720 DOWNSTREAM_3'UTR 21 37 58
# >M03997:68:000000000-G35DK:1:1102:17834:17785 DOWNSTREAM_3'UTR 22 39 61
# >M03997:68:000000000-G35DK:1:2104:13930:26976 DOWNSTREAM_3'UTR 15 23 38
# >M03997:68:000000000-G35DK:1:2101:26905:18472 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 23 98 121
# >M03997:68:000000000-G35DK:1:2102:17625:25451 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 10 199 209
# >M03997:68:000000000-G35DK:1:2103:8395:18761 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 16 108 124
# >M03997:68:000000000-G35DK:1:2103:26212:12991 FP+UPSTREAM_3'UTR+BD 18 84 102
# >M03997:68:000000000-G35DK:1:1101:13003:15047 FP+UPSTREAM_3'UTR+BD 22 88 110
# >M03997:68:000000000-G35DK:1:1102:27915:13919 FP+UPSTREAM_3'UTR 9 20 29
# >M03997:68:000000000-G35DK:1:1101:7231:16554 FP+UPSTREAM_3'UTR 9 30 39
# >M03997:68:000000000-G35DK:1:2103:5786:15081 FP+UPSTREAM_3'UTR 9 27 36
# >M03997:68:000000000-G35DK:1:2101:2642:10843 FP+UPSTREAM_3'UTR 9 32 41
# >M03997:68:000000000-G35DK:1:1101:20576:23901 FP+UPSTREAM_3'UTR 18 20 38
# >M03997:68:000000000-G35DK:1:2104:25628:14997 FP+UPSTREAM_3'UTR 9 31 40
# >M03997:68:000000000-G35DK:1:1102:13204:18851 FP+UPSTREAM_3'UTR 19 24 43
# >M03997:68:000000000-G35DK:1:2101:5250:14539 FP+UPSTREAM_3'UTR 15 30 45
# >M03997:68:000000000-G35DK:1:2101:18361:4564 FP+UPSTREAM_3'UTR 31 19 50
# >M03997:68:000000000-G35DK:1:1103:16426:25845 FP+UPSTREAM_3'UTR 15 30 45
# >M03997:68:000000000-G35DK:1:2104:7995:8218 FP+UPSTREAM_3'UTR 11 26 37
# >M03997:68:000000000-G35DK:1:1103:3169:17746 FP+UPSTREAM_3'UTR 25 151 176
# >M03997:68:000000000-G35DK:1:1103:4486:17134 FP+UPSTREAM_3'UTR 14 26 40
# >M03997:68:000000000-G35DK:1:2104:10559:20118 FP+UPSTREAM_3'UTR 9 31 40
# >M03997:68:000000000-G35DK:1:1101:19724:8153 FP+UPSTREAM_3'UTR 9 31 40
# >M03997:68:000000000-G35DK:1:1102:12470:9137 FP+UPSTREAM_3'UTR 9 30 39
# >M03997:68:000000000-G35DK:1:1104:18935:13846 FP+UPSTREAM_3'UTR 15 31 46
# >M03997:68:000000000-G35DK:1:1104:22036:14821 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 15 67 82
# >M03997:68:000000000-G35DK:1:2102:6951:23284 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 29 81 110
# >M03997:68:000000000-G35DK:1:1104:21489:17001 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 16 116 132
# >M03997:68:000000000-G35DK:1:2103:4021:19896 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 17 57 74
# >M03997:68:000000000-G35DK:1:1103:24596:20653 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 18 78 96
# >M03997:68:000000000-G35DK:1:1101:2383:16327 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 9 42 51
# >M03997:68:000000000-G35DK:1:1101:23199:22440 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 17 133 150
# >M03997:68:000000000-G35DK:1:1104:6165:12703 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 38 57
# >M03997:68:000000000-G35DK:1:2101:9333:17497 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 26 38 64
# >M03997:68:000000000-G35DK:1:1104:13258:24778 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 11 87 98
# >M03997:68:000000000-G35DK:1:1104:16497:18553 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 23 88 111
# >M03997:68:000000000-G35DK:1:2101:16241:6199 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 14 134 148
# >M03997:68:000000000-G35DK:1:2101:19660:6213 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 21 42 63
# >M03997:68:000000000-G35DK:1:1103:12089:10320 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 20 83 103
# >M03997:68:000000000-G35DK:1:1104:26565:7916 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 38 80 118
# >M03997:68:000000000-G35DK:1:1101:14302:22925 UPSTREAM_3'UTR+BD 36 51 87
# >M03997:68:000000000-G35DK:1:2104:17408:27665 BD+DOWNSTREAM_3'UTR 13 46 59
# 7 >M03997:68:000000000-G35DK:1:1103:22878:4987 72 79
# 11 >M03997:68:000000000-G35DK:1:1103:22878:4987 147 158
# 9 >M03997:68:000000000-G35DK:1:1101:23951:17954 32 41
# 13 >M03997:68:000000000-G35DK:1:1101:23951:17954 109 122
# 6 >M03997:68:000000000-G35DK:1:1101:23951:17954 124 130
# 30 >M03997:68:000000000-G35DK:1:1104:18371:21267 45 75
# 7 >M03997:68:000000000-G35DK:1:1104:18371:21267 86 93
# 5 >M03997:68:000000000-G35DK:1:1104:18371:21267 104 109
# 12 >M03997:68:000000000-G35DK:1:1104:18371:21267 143 155
# 14 >M03997:68:000000000-G35DK:1:1101:21993:26823 70 84
# 5 >M03997:68:000000000-G35DK:1:1103:17213:15288 49 54
# 9 >M03997:68:000000000-G35DK:1:2101:6155:21319 32 41
# 21 >M03997:68:000000000-G35DK:1:1101:20334:7334 43 64
# 22 >M03997:68:000000000-G35DK:1:2103:12471:4180 41 63
# 5 >M03997:68:000000000-G35DK:1:2103:12471:4180 92 97
# 15 >M03997:68:000000000-G35DK:1:2103:12471:4180 129 144
# 5 >M03997:68:000000000-G35DK:1:2103:12471:4180 229 234
# 21 >M03997:68:000000000-G35DK:1:2104:27709:12302 46 67
# 6 >M03997:68:000000000-G35DK:1:2104:27709:12302 90 96
# 12 >M03997:68:000000000-G35DK:1:2104:27709:12302 145 157
# 21 >M03997:68:000000000-G35DK:1:1104:22582:12720 37 58
# 22 >M03997:68:000000000-G35DK:1:1102:17834:17785 39 61
# 8 >M03997:68:000000000-G35DK:1:1102:17834:17785 139 147
# 9 >M03997:68:000000000-G35DK:1:1102:17834:17785 148 157
# 15 >M03997:68:000000000-G35DK:1:2104:13930:26976 23 38
# 13 >M03997:68:000000000-G35DK:1:2104:13930:26976 109 122
# 8 >M03997:68:000000000-G35DK:1:2104:13930:26976 144 152
# 12 >M03997:68:000000000-G35DK:1:2104:13930:26976 162 174
# 7 >M03997:68:000000000-G35DK:1:1103:18432:4010 45 52
# 21 >M03997:68:000000000-G35DK:1:2101:26905:18472 98 119
# 5 >M03997:68:000000000-G35DK:1:2101:26905:18472 158 163
# 10 >M03997:68:000000000-G35DK:1:2102:17625:25451 199 209
# 16 >M03997:68:000000000-G35DK:1:2103:8395:18761 108 124
# 8 >M03997:68:000000000-G35DK:1:2103:8395:18761 203 211
# 18 >M03997:68:000000000-G35DK:1:2103:26212:12991 84 102
# 22 >M03997:68:000000000-G35DK:1:1101:13003:15047 88 110
# 11 >M03997:68:000000000-G35DK:1:1101:13003:15047 189 200
# 5 >M03997:68:000000000-G35DK:1:1102:11956:12171 94 99
# 22 >M03997:68:000000000-G35DK:1:2103:5786:15081 49 71
# 5 >M03997:68:000000000-G35DK:1:2103:5786:15081 91 96
# 7 >M03997:68:000000000-G35DK:1:2103:5786:15081 166 173
# 5 >M03997:68:000000000-G35DK:1:2103:5786:15081 273 278
# 5 >M03997:68:000000000-G35DK:1:1103:27516:19170 46 51
# 7 >M03997:68:000000000-G35DK:1:1103:14624:9917 20 27
# 18 >M03997:68:000000000-G35DK:1:1101:20576:23901 20 38
# 19 >M03997:68:000000000-G35DK:1:1102:13204:18851 24 43
# 11 >M03997:68:000000000-G35DK:1:1102:13204:18851 115 126
# 5 >M03997:68:000000000-G35DK:1:1102:13204:18851 281 286
# 15 >M03997:68:000000000-G35DK:1:2101:5250:14539 30 45
# 31 >M03997:68:000000000-G35DK:1:2101:18361:4564 19 50
# 5 >M03997:68:000000000-G35DK:1:2101:18361:4564 89 94
# 14 >M03997:68:000000000-G35DK:1:2101:18361:4564 126 140
# 15 >M03997:68:000000000-G35DK:1:1103:16426:25845 30 45
# 10 >M03997:68:000000000-G35DK:1:1103:16426:25845 122 132
# 25 >M03997:68:000000000-G35DK:1:1103:3169:17746 151 176
# 14 >M03997:68:000000000-G35DK:1:1103:4486:17134 26 40
# 9 >M03997:68:000000000-G35DK:1:1103:4486:17134 115 124
# 15 >M03997:68:000000000-G35DK:1:1104:18935:13846 31 46
# 10 >M03997:68:000000000-G35DK:1:1104:18935:13846 123 133
# 15 >M03997:68:000000000-G35DK:1:1104:22036:14821 67 82
# 9 >M03997:68:000000000-G35DK:1:1104:22036:14821 161 170
# 29 >M03997:68:000000000-G35DK:1:2102:6951:23284 81 110
# 5 >M03997:68:000000000-G35DK:1:2102:6951:23284 139 144
# 10 >M03997:68:000000000-G35DK:1:2102:6951:23284 181 191
# 16 >M03997:68:000000000-G35DK:1:1104:21489:17001 117 133
# 6 >M03997:68:000000000-G35DK:1:1102:2967:15562 105 111
# 17 >M03997:68:000000000-G35DK:1:2103:4021:19896 57 74
# 18 >M03997:68:000000000-G35DK:1:1103:24596:20653 78 96
# 6 >M03997:68:000000000-G35DK:1:1103:24596:20653 132 138
# 9 >M03997:68:000000000-G35DK:1:1101:2383:16327 42 51
# 7 >M03997:68:000000000-G35DK:1:1101:10341:20156 47 54
# 17 >M03997:68:000000000-G35DK:1:1101:23199:22440 133 150
# 7 >M03997:68:000000000-G35DK:1:1101:23199:22440 229 236
# 5 >M03997:68:000000000-G35DK:1:1103:26230:20057 103 108
# 19 >M03997:68:000000000-G35DK:1:1104:6165:12703 38 57
# 6 >M03997:68:000000000-G35DK:1:1104:6165:12703 129 135
# 26 >M03997:68:000000000-G35DK:1:2101:9333:17497 38 64
# 5 >M03997:68:000000000-G35DK:1:2101:9333:17497 94 99
# 11 >M03997:68:000000000-G35DK:1:2101:9333:17497 100 111
# 10 >M03997:68:000000000-G35DK:1:2101:9333:17497 140 150
# 10 >M03997:68:000000000-G35DK:1:2101:9333:17497 201 211
# 5 >M03997:68:000000000-G35DK:1:2101:9333:17497 215 220
# 11 >M03997:68:000000000-G35DK:1:1104:13258:24778 87 98
# 23 >M03997:68:000000000-G35DK:1:1104:16497:18553 88 111
# 14 >M03997:68:000000000-G35DK:1:2101:16241:6199 134 148
# 6 >M03997:68:000000000-G35DK:1:1102:19667:6905 44 50
# 21 >M03997:68:000000000-G35DK:1:2101:19660:6213 42 63
# 6 >M03997:68:000000000-G35DK:1:1103:10587:12132 65 71
# 20 >M03997:68:000000000-G35DK:1:1103:12089:10320 83 103
# 36 >M03997:68:000000000-G35DK:1:1104:26565:7916 80 116
# 6 >M03997:68:000000000-G35DK:1:1104:26565:7916 194 200
# 36 >M03997:68:000000000-G35DK:1:1101:14302:22925 51 87
# 7 >M03997:68:000000000-G35DK:1:1101:14302:22925 94 101
# 5 >M03997:68:000000000-G35DK:1:1101:14302:22925 153 158
# 5 >M03997:68:000000000-G35DK:1:2104:9664:26955 48 53
# 13 >M03997:68:000000000-G35DK:1:2104:17408:27665 46 59
# >M03997:68:000000000-G35DK:1:1103:16077:15313 UPSTREAM_3'UTR 14 44 58
# >M03997:68:000000000-G35DK:1:2104:15459:7890 DOWNSTREAM_3'UTR 12 69 81
# >M03997:68:000000000-G35DK:1:2102:17750:7892 DOWNSTREAM_3'UTR 11 28 39
# >M03997:68:000000000-G35DK:1:1104:7806:16089 DOWNSTREAM_3'UTR 23 27 50
# >M03997:68:000000000-G35DK:1:2102:3852:9852 DOWNSTREAM_3'UTR 10 28 38
# >M03997:68:000000000-G35DK:1:2102:18067:15454 DOWNSTREAM_3'UTR 46 44 90
# >M03997:68:000000000-G35DK:1:1101:12398:14765 DOWNSTREAM_3'UTR 16 31 47
# >M03997:68:000000000-G35DK:1:1104:25960:21013 DOWNSTREAM_3'UTR 22 37 59
# >M03997:68:000000000-G35DK:1:2103:5745:12777 DOWNSTREAM_3'UTR 12 25 37
# >M03997:68:000000000-G35DK:1:2101:18669:24904 DOWNSTREAM_3'UTR 17 58 75
# >M03997:68:000000000-G35DK:1:2104:7809:13176 DOWNSTREAM_3'UTR 17 38 55
# >M03997:68:000000000-G35DK:1:2104:18659:23454 DOWNSTREAM_3'UTR 18 73 91
# >M03997:68:000000000-G35DK:1:2104:24422:11875 DOWNSTREAM_3'UTR 25 48 73
# >M03997:68:000000000-G35DK:1:1101:6752:19798 DOWNSTREAM_3'UTR 19 44 63
# >M03997:68:000000000-G35DK:1:2101:17856:11547 DOWNSTREAM_3'UTR 27 38 65
# >M03997:68:000000000-G35DK:1:1102:22788:21050 DOWNSTREAM_3'UTR 21 26 47
# >M03997:68:000000000-G35DK:1:2102:19941:9064 DOWNSTREAM_3'UTR 12 176 188
# >M03997:68:000000000-G35DK:1:1101:7815:17822 DOWNSTREAM_3'UTR 14 42 56
# >M03997:68:000000000-G35DK:1:1104:23040:10299 DOWNSTREAM_3'UTR 13 35 48
# >M03997:68:000000000-G35DK:1:2104:3782:14112 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 16 98 114
# >M03997:68:000000000-G35DK:1:1103:16776:9294 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 13 117 130
# >M03997:68:000000000-G35DK:1:1102:16618:3741 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 10 160 170
# >M03997:68:000000000-G35DK:1:2102:15675:25103 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 18 150 168
# >M03997:68:000000000-G35DK:1:1101:5227:15872 FP+UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 25 106 131
# >M03997:68:000000000-G35DK:1:2101:6301:19622 FP+UPSTREAM_3'UTR 17 45 62
# >M03997:68:000000000-G35DK:1:1102:15443:25484 FP+UPSTREAM_3'UTR 12 142 154
# >M03997:68:000000000-G35DK:1:1102:21054:5393 FP+UPSTREAM_3'UTR 9 33 42
# >M03997:68:000000000-G35DK:1:1101:12776:15873 FP+UPSTREAM_3'UTR 13 81 94
# >M03997:68:000000000-G35DK:1:2101:17113:22505 FP+UPSTREAM_3'UTR 26 89 115
# >M03997:68:000000000-G35DK:1:2101:10942:26461 FP+UPSTREAM_3'UTR 15 30 45
# >M03997:68:000000000-G35DK:1:1103:21440:8870 FP+UPSTREAM_3'UTR 11 28 39
# >M03997:68:000000000-G35DK:1:1102:26770:23100 FP+UPSTREAM_3'UTR 21 27 48
# >M03997:68:000000000-G35DK:1:2101:17522:16726 FP+UPSTREAM_3'UTR 25 21 46
# >M03997:68:000000000-G35DK:1:1101:11351:16262 FP+UPSTREAM_3'UTR 10 70 80
# >M03997:68:000000000-G35DK:1:1101:10802:14437 FP+UPSTREAM_3'UTR 28 34 62
# >M03997:68:000000000-G35DK:1:1101:25460:11400 FP+UPSTREAM_3'UTR 14 79 93
# >M03997:68:000000000-G35DK:1:1104:18418:19852 FP+UPSTREAM_3'UTR 29 25 54
# >M03997:68:000000000-G35DK:1:1102:28765:13606 FP+UPSTREAM_3'UTR 13 29 42
# >M03997:68:000000000-G35DK:1:2102:16931:6889 FP+UPSTREAM_3'UTR 9 31 40
# >M03997:68:000000000-G35DK:1:2104:5465:11268 FP+UPSTREAM_3'UTR 14 37 51
# >M03997:68:000000000-G35DK:1:2101:22469:20329 FP+UPSTREAM_3'UTR 20 24 44
# >M03997:68:000000000-G35DK:1:2102:28622:19975 FP+UPSTREAM_3'UTR 12 28 40
# >M03997:68:000000000-G35DK:1:1103:15540:16869 FP+UPSTREAM_3'UTR 16 25 41
# >M03997:68:000000000-G35DK:1:2104:13860:4916 FP+UPSTREAM_3'UTR 9 28 37
# >M03997:68:000000000-G35DK:1:1104:17528:21914 FP+UPSTREAM_3'UTR 26 30 56
# >M03997:68:000000000-G35DK:1:1103:14855:6982 FP+UPSTREAM_3'UTR 28 26 54
# >M03997:68:000000000-G35DK:1:1102:8667:7165 FP+UPSTREAM_3'UTR 18 131 149
# >M03997:68:000000000-G35DK:1:2102:6138:9868 FP+UPSTREAM_3'UTR 12 20 32
# >M03997:68:000000000-G35DK:1:1102:11526:17379 FP+UPSTREAM_3'UTR 18 53 71
# >M03997:68:000000000-G35DK:1:1102:10080:17971 FP+UPSTREAM_3'UTR 20 28 48
# >M03997:68:000000000-G35DK:1:2102:12366:22691 FP+UPSTREAM_3'UTR 20 38 58
# >M03997:68:000000000-G35DK:1:2101:8541:22760 FP+UPSTREAM_3'UTR 9 31 40
# >M03997:68:000000000-G35DK:1:1101:25172:20738 FP+UPSTREAM_3'UTR 9 31 40
# >M03997:68:000000000-G35DK:1:2104:20415:9357 FP+UPSTREAM_3'UTR 22 30 52
# >M03997:68:000000000-G35DK:1:2104:15276:27589 FP+UPSTREAM_3'UTR 24 59 83
# >M03997:68:000000000-G35DK:1:1101:11857:8378 FP+UPSTREAM_3'UTR 16 26 42
# >M03997:68:000000000-G35DK:1:1101:9174:12828 FP+UPSTREAM_3'UTR 14 28 42
# >M03997:68:000000000-G35DK:1:1103:10793:9760 FP+UPSTREAM_3'UTR 15 25 40
# >M03997:68:000000000-G35DK:1:1102:17165:4361 FP+UPSTREAM_3'UTR 10 17 27
# >M03997:68:000000000-G35DK:1:1103:14985:15841 FP+UPSTREAM_3'UTR 17 140 157
# >M03997:68:000000000-G35DK:1:1104:24598:6776 FP+UPSTREAM_3'UTR 24 81 105
# >M03997:68:000000000-G35DK:1:1104:8662:17361 FP+UPSTREAM_3'UTR 12 19 31
# >M03997:68:000000000-G35DK:1:1102:14277:24461 FP+UPSTREAM_3'UTR 27 36 63
# >M03997:68:000000000-G35DK:1:1102:24506:16763 FP+UPSTREAM_3'UTR 19 27 46
# >M03997:68:000000000-G35DK:1:1104:6969:11828 FP+UPSTREAM_3'UTR 13 27 40
# >M03997:68:000000000-G35DK:1:2103:19939:26427 FP+UPSTREAM_3'UTR 9 24 33
# >M03997:68:000000000-G35DK:1:2102:11615:14652 FP+UPSTREAM_3'UTR 14 63 77
# >M03997:68:000000000-G35DK:1:2102:8801:9641 FP+UPSTREAM_3'UTR 26 145 171
# >M03997:68:000000000-G35DK:1:1103:4166:12434 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 13 217 230
# >M03997:68:000000000-G35DK:1:1102:5580:16442 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 15 71 86
# >M03997:68:000000000-G35DK:1:1104:16675:6391 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 14 91 105
# >M03997:68:000000000-G35DK:1:1101:19377:13486 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 15 65 80
# >M03997:68:000000000-G35DK:1:2102:22708:14003 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 18 94 112
# >M03997:68:000000000-G35DK:1:1104:12547:5412 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 104 123
# >M03997:68:000000000-G35DK:1:1104:11990:12620 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 97 116
# >M03997:68:000000000-G35DK:1:1101:15962:16354 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 22 93 115
# >M03997:68:000000000-G35DK:1:2102:27716:10247 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 21 28 49
# >M03997:68:000000000-G35DK:1:2103:2522:12728 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 13 51 64
# >M03997:68:000000000-G35DK:1:1101:5313:24588 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 47 66
# >M03997:68:000000000-G35DK:1:1103:2622:11141 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 17 115 132
# >M03997:68:000000000-G35DK:1:2101:19813:11392 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 22 76 98
# >M03997:68:000000000-G35DK:1:2104:22605:15568 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 30 103 133
# >M03997:68:000000000-G35DK:1:2102:19058:7977 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 34 78 112
# >M03997:68:000000000-G35DK:1:1104:22927:4275 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 15 74 89
# >M03997:68:000000000-G35DK:1:1101:23992:18247 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 20 86 106
# >M03997:68:000000000-G35DK:1:1101:11678:27908 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 15 99 114
# >M03997:68:000000000-G35DK:1:1101:26058:15742 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 13 83 96
# >M03997:68:000000000-G35DK:1:1101:21231:26942 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 20 38 58
# >M03997:68:000000000-G35DK:1:2101:5943:23471 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 13 88 101
# >M03997:68:000000000-G35DK:1:2103:22258:25924 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 15 83 98
# >M03997:68:000000000-G35DK:1:2104:26827:12140 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 15 97 112
# >M03997:68:000000000-G35DK:1:1103:13420:6518 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 22 150 172
# >M03997:68:000000000-G35DK:1:1103:19318:25443 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 18 72 90
# >M03997:68:000000000-G35DK:1:2102:15078:4961 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 20 38 58
# >M03997:68:000000000-G35DK:1:1101:21904:13492 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 30 98 128
# >M03997:68:000000000-G35DK:1:1104:17914:18200 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 11 88 99
# >M03997:68:000000000-G35DK:1:2103:13773:7473 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 18 126 144
# >M03997:68:000000000-G35DK:1:2104:21694:11090 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 13 141 154
# >M03997:68:000000000-G35DK:1:1104:20970:5180 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 24 70 94
# >M03997:68:000000000-G35DK:1:1103:11451:19125 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 89 108
# >M03997:68:000000000-G35DK:1:2104:7598:22911 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 12 107 119
# >M03997:68:000000000-G35DK:1:1103:21466:18005 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 14 58 72
# >M03997:68:000000000-G35DK:1:1101:9169:8613 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 14 97 111
# >M03997:68:000000000-G35DK:1:2102:20180:22180 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 97 116
# >M03997:68:000000000-G35DK:1:1103:7354:15923 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 33 128 161
# >M03997:68:000000000-G35DK:1:2103:6841:7774 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 18 38 56
# >M03997:68:000000000-G35DK:1:1102:27156:7579 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 14 118 132
# >M03997:68:000000000-G35DK:1:2104:24110:5397 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 18 38 56
# >M03997:68:000000000-G35DK:1:1101:13251:10234 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 16 25 41
# >M03997:68:000000000-G35DK:1:2101:17669:22337 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 13 142 155
# >M03997:68:000000000-G35DK:1:2104:16872:6556 UPSTREAM_3'UTR+BD 15 41 56
# >M03997:68:000000000-G35DK:1:2104:28497:18667 BD+DOWNSTREAM_3'UTR 20 48 68
# >M03997:68:000000000-G35DK:1:2103:9942:3002 BD+DOWNSTREAM_3'UTR 15 52 67
# >M03997:68:000000000-G35DK:1:1101:14013:10009 BD+DOWNSTREAM_3'UTR 40 64 104
# >M03997:68:000000000-G35DK:1:2102:12059:16786 BD+DOWNSTREAM_3'UTR 16 52 68
# >M03997:68:000000000-G35DK:1:2101:23744:12747 BD+DOWNSTREAM_3'UTR 28 59 87
# 14 >M03997:68:000000000-G35DK:1:1103:16077:15313 44 58
# 12 >M03997:68:000000000-G35DK:1:2104:15459:7890 69 81
# 12 >M03997:68:000000000-G35DK:1:2104:15459:7890 154 166
# 11 >M03997:68:000000000-G35DK:1:2102:17750:7892 29 40
# 21 >M03997:68:000000000-G35DK:1:1104:7806:16089 27 48
# 10 >M03997:68:000000000-G35DK:1:2102:3852:9852 28 38
# 38 >M03997:68:000000000-G35DK:1:2102:18067:15454 43 81
# 6 >M03997:68:000000000-G35DK:1:2102:18067:15454 82 88
# 10 >M03997:68:000000000-G35DK:1:2102:18067:15454 90 100
# 9 >M03997:68:000000000-G35DK:1:2102:18067:15454 116 125
# 7 >M03997:68:000000000-G35DK:1:2102:18067:15454 152 159
# 6 >M03997:68:000000000-G35DK:1:2102:18067:15454 277 283
# 16 >M03997:68:000000000-G35DK:1:1101:12398:14765 31 47
# 5 >M03997:68:000000000-G35DK:1:1101:12398:14765 69 74
# 8 >M03997:68:000000000-G35DK:1:1101:12398:14765 95 103
# 11 >M03997:68:000000000-G35DK:1:1101:12398:14765 124 135
# 6 >M03997:68:000000000-G35DK:1:1101:12398:14765 158 164
# 5 >M03997:68:000000000-G35DK:1:1101:12398:14765 194 199
# 22 >M03997:68:000000000-G35DK:1:1104:25960:21013 37 59
# 9 >M03997:68:000000000-G35DK:1:1104:25960:21013 131 140
# 12 >M03997:68:000000000-G35DK:1:2103:5745:12777 25 37
# 17 >M03997:68:000000000-G35DK:1:2101:18669:24904 58 75
# 6 >M03997:68:000000000-G35DK:1:2101:18669:24904 96 102
# 7 >M03997:68:000000000-G35DK:1:2101:18669:24904 152 159
# 5 >M03997:68:000000000-G35DK:1:1102:13169:19933 31 36
# 17 >M03997:68:000000000-G35DK:1:2104:7809:13176 38 55
# 18 >M03997:68:000000000-G35DK:1:2104:18659:23454 73 91
# 8 >M03997:68:000000000-G35DK:1:2104:18659:23454 109 117
# 7 >M03997:68:000000000-G35DK:1:2104:18659:23454 166 173
# 5 >M03997:68:000000000-G35DK:1:2104:18659:23454 286 291
# 25 >M03997:68:000000000-G35DK:1:2104:24422:11875 48 73
# 19 >M03997:68:000000000-G35DK:1:1101:6752:19798 44 63
# 5 >M03997:68:000000000-G35DK:1:1101:6752:19798 141 146
# 25 >M03997:68:000000000-G35DK:1:2101:17856:11547 38 63
# 7 >M03997:68:000000000-G35DK:1:2101:17856:11547 99 106
# 8 >M03997:68:000000000-G35DK:1:2101:17856:11547 132 140
# 5 >M03997:68:000000000-G35DK:1:2102:27001:11523 27 32
# 21 >M03997:68:000000000-G35DK:1:1102:22788:21050 26 47
# 6 >M03997:68:000000000-G35DK:1:1102:22788:21050 93 99
# 10 >M03997:68:000000000-G35DK:1:1102:22788:21050 121 131
# 6 >M03997:68:000000000-G35DK:1:2102:19941:9064 175 181
# 14 >M03997:68:000000000-G35DK:1:1101:7815:17822 42 56
# 13 >M03997:68:000000000-G35DK:1:1104:23040:10299 35 48
# 16 >M03997:68:000000000-G35DK:1:2104:3782:14112 98 114
# 7 >M03997:68:000000000-G35DK:1:2104:3782:14112 194 201
# 13 >M03997:68:000000000-G35DK:1:1103:16776:9294 117 130
# 12 >M03997:68:000000000-G35DK:1:1103:16776:9294 207 219
# 10 >M03997:68:000000000-G35DK:1:1102:16618:3741 160 170
# 18 >M03997:68:000000000-G35DK:1:2102:15675:25103 150 168
# 25 >M03997:68:000000000-G35DK:1:1101:5227:15872 106 131
# 5 >M03997:68:000000000-G35DK:1:1104:26211:12399 94 99
# 17 >M03997:68:000000000-G35DK:1:2101:6301:19622 45 62
# 9 >M03997:68:000000000-G35DK:1:1102:15443:25484 142 151
# 25 >M03997:68:000000000-G35DK:1:1102:21054:5393 54 79
# 5 >M03997:68:000000000-G35DK:1:1102:21054:5393 92 97
# 6 >M03997:68:000000000-G35DK:1:1102:21054:5393 121 127
# 13 >M03997:68:000000000-G35DK:1:1101:12776:15873 81 94
# 26 >M03997:68:000000000-G35DK:1:2101:17113:22505 89 115
# 15 >M03997:68:000000000-G35DK:1:2101:10942:26461 30 45
# 15 >M03997:68:000000000-G35DK:1:2101:10942:26461 122 137
# 11 >M03997:68:000000000-G35DK:1:1103:21440:8870 28 39
# 21 >M03997:68:000000000-G35DK:1:1102:26770:23100 27 48
# 7 >M03997:68:000000000-G35DK:1:1102:26770:23100 115 122
# 25 >M03997:68:000000000-G35DK:1:2101:17522:16726 21 46
# 5 >M03997:68:000000000-G35DK:1:2101:17522:16726 90 95
# 10 >M03997:68:000000000-G35DK:1:2101:17522:16726 117 127
# 5 >M03997:68:000000000-G35DK:1:2101:17522:16726 135 140
# 5 >M03997:68:000000000-G35DK:1:2101:17522:16726 162 167
# 5 >M03997:68:000000000-G35DK:1:1101:11351:16262 70 75
# 28 >M03997:68:000000000-G35DK:1:1101:10802:14437 34 62
# 9 >M03997:68:000000000-G35DK:1:1101:10802:14437 134 143
# 14 >M03997:68:000000000-G35DK:1:1101:25460:11400 79 93
# 29 >M03997:68:000000000-G35DK:1:1104:18418:19852 25 54
# 8 >M03997:68:000000000-G35DK:1:1104:18418:19852 91 99
# 10 >M03997:68:000000000-G35DK:1:1104:18418:19852 126 136
# 5 >M03997:68:000000000-G35DK:1:1104:18418:19852 152 157
# 13 >M03997:68:000000000-G35DK:1:1102:28765:13606 29 42
# 5 >M03997:68:000000000-G35DK:1:2101:21645:27337 66 71
# 14 >M03997:68:000000000-G35DK:1:2104:5465:11268 37 51
# 7 >M03997:68:000000000-G35DK:1:2104:5465:11268 128 135
# 20 >M03997:68:000000000-G35DK:1:2101:22469:20329 25 45
# 12 >M03997:68:000000000-G35DK:1:2102:28622:19975 28 40
# 5 >M03997:68:000000000-G35DK:1:2102:17191:25187 65 70
# 16 >M03997:68:000000000-G35DK:1:1103:15540:16869 25 41
# 6 >M03997:68:000000000-G35DK:1:2102:13714:17137 68 74
# 26 >M03997:68:000000000-G35DK:1:1104:17528:21914 30 56
# 8 >M03997:68:000000000-G35DK:1:1104:17528:21914 92 100
# 5 >M03997:68:000000000-G35DK:1:1104:17528:21914 105 110
# 11 >M03997:68:000000000-G35DK:1:1103:14855:6982 26 37
# 16 >M03997:68:000000000-G35DK:1:1103:14855:6982 38 54
# 11 >M03997:68:000000000-G35DK:1:1103:14855:6982 133 144
# 18 >M03997:68:000000000-G35DK:1:1102:8667:7165 131 149
# 12 >M03997:68:000000000-G35DK:1:2102:6138:9868 20 32
# 5 >M03997:68:000000000-G35DK:1:1102:11526:17379 45 50
# 18 >M03997:68:000000000-G35DK:1:1102:11526:17379 53 71
# 7 >M03997:68:000000000-G35DK:1:1102:11526:17379 88 95
# 7 >M03997:68:000000000-G35DK:1:1102:11526:17379 104 111
# 20 >M03997:68:000000000-G35DK:1:1102:10080:17971 28 48
# 9 >M03997:68:000000000-G35DK:1:1102:10080:17971 87 96
# 9 >M03997:68:000000000-G35DK:1:1102:10080:17971 117 126
# 20 >M03997:68:000000000-G35DK:1:2102:12366:22691 38 58
# 18 >M03997:68:000000000-G35DK:1:2101:8541:22760 51 69
# 7 >M03997:68:000000000-G35DK:1:2101:8541:22760 81 88
# 10 >M03997:68:000000000-G35DK:1:2101:8541:22760 141 151
# 19 >M03997:68:000000000-G35DK:1:1101:25172:20738 61 80
# 22 >M03997:68:000000000-G35DK:1:2104:20415:9357 30 52
# 7 >M03997:68:000000000-G35DK:1:2104:20415:9357 92 99
# 7 >M03997:68:000000000-G35DK:1:2104:20415:9357 120 127
# 5 >M03997:68:000000000-G35DK:1:2104:20415:9357 130 135
# 5 >M03997:68:000000000-G35DK:1:2103:14754:21700 66 71
# 20 >M03997:68:000000000-G35DK:1:2104:15276:27589 63 83
# 6 >M03997:68:000000000-G35DK:1:2104:15276:27589 164 170
# 16 >M03997:68:000000000-G35DK:1:1101:11857:8378 26 42
# 14 >M03997:68:000000000-G35DK:1:1101:9174:12828 28 42
# 15 >M03997:68:000000000-G35DK:1:1103:10793:9760 25 40
# 10 >M03997:68:000000000-G35DK:1:1102:17165:4361 18 28
# 17 >M03997:68:000000000-G35DK:1:1103:14985:15841 140 157
# 20 >M03997:68:000000000-G35DK:1:1104:24598:6776 85 105
# 5 >M03997:68:000000000-G35DK:1:1104:24598:6776 151 156
# 16 >M03997:68:000000000-G35DK:1:1104:24598:6776 177 193
# 6 >M03997:68:000000000-G35DK:1:1104:24598:6776 279 285
# 12 >M03997:68:000000000-G35DK:1:1104:8662:17361 19 31
# 23 >M03997:68:000000000-G35DK:1:1102:14277:24461 36 59
# 7 >M03997:68:000000000-G35DK:1:1102:14277:24461 89 96
# 11 >M03997:68:000000000-G35DK:1:1102:14277:24461 132 143
# 19 >M03997:68:000000000-G35DK:1:1102:24506:16763 27 46
# 6 >M03997:68:000000000-G35DK:1:1102:24506:16763 69 75
# 5 >M03997:68:000000000-G35DK:1:1102:24506:16763 99 104
# 8 >M03997:68:000000000-G35DK:1:1102:24506:16763 125 133
# 13 >M03997:68:000000000-G35DK:1:1104:6969:11828 27 40
# 5 >M03997:68:000000000-G35DK:1:1101:16053:27565 24 29
# 14 >M03997:68:000000000-G35DK:1:2102:11615:14652 63 77
# 26 >M03997:68:000000000-G35DK:1:2102:8801:9641 145 171
# 5 >M03997:68:000000000-G35DK:1:2102:8801:9641 184 189
# 8 >M03997:68:000000000-G35DK:1:2102:8801:9641 244 252
# 5 >M03997:68:000000000-G35DK:1:1103:4166:12434 140 145
# 7 >M03997:68:000000000-G35DK:1:1103:4166:12434 221 228
# 15 >M03997:68:000000000-G35DK:1:1102:5580:16442 71 86
# 14 >M03997:68:000000000-G35DK:1:1104:16675:6391 91 105
# 7 >M03997:68:000000000-G35DK:1:1104:16675:6391 154 161
# 7 >M03997:68:000000000-G35DK:1:1104:16675:6391 185 192
# 15 >M03997:68:000000000-G35DK:1:1101:19377:13486 65 80
# 6 >M03997:68:000000000-G35DK:1:1101:19377:13486 154 160
# 18 >M03997:68:000000000-G35DK:1:2102:22708:14003 94 112
# 7 >M03997:68:000000000-G35DK:1:2102:22708:14003 183 190
# 5 >M03997:68:000000000-G35DK:1:2102:22708:14003 245 250
# ...
# >M03997:68:000000000-G35DK:1:1104:11157:11264 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 25 79 104
# >M03997:68:000000000-G35DK:1:1101:10859:20693 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 25 125 150
# >M03997:68:000000000-G35DK:1:1103:22856:7778 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 22 63 85
# >M03997:68:000000000-G35DK:1:1101:25055:13448 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 15 121 136
# >M03997:68:000000000-G35DK:1:2101:11698:20951 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 17 62 79
# >M03997:68:000000000-G35DK:1:2101:11721:12872 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 12 132 144
# >M03997:68:000000000-G35DK:1:1104:18717:22333 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 20 102 122
# >M03997:68:000000000-G35DK:1:1103:8363:11858 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 14 74 88
# >M03997:68:000000000-G35DK:1:2101:8407:23573 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 13 98 111
# >M03997:68:000000000-G35DK:1:1101:6016:11810 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 15 28 43
# >M03997:68:000000000-G35DK:1:2102:20791:8313 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 15 109 124
# >M03997:68:000000000-G35DK:1:1101:25467:14593 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 80 99
# >M03997:68:000000000-G35DK:1:2103:10306:4367 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 17 68 85
# >M03997:68:000000000-G35DK:1:2104:9118:13431 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 17 72 89
# >M03997:68:000000000-G35DK:1:2101:11512:3024 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 29 68 97
# >M03997:68:000000000-G35DK:1:1103:15695:7962 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 16 57 73
# >M03997:68:000000000-G35DK:1:2102:15270:7183 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 11 85 96
# >M03997:68:000000000-G35DK:1:1101:6817:10866 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 16 57 73
# >M03997:68:000000000-G35DK:1:1104:17544:13177 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 33 88 121
# >M03997:68:000000000-G35DK:1:1104:20193:24822 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 14 90 104
# >M03997:68:000000000-G35DK:1:1102:22849:20903 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 16 67 83
# >M03997:68:000000000-G35DK:1:1101:4516:12146 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 19 72 91
# >M03997:68:000000000-G35DK:1:1103:3874:17211 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 17 109 126
# >M03997:68:000000000-G35DK:1:1102:16365:14360 UPSTREAM_3'UTR+BD+DOWNSTREAM_3'UTR 14 109 123
# >M03997:68:000000000-G35DK:1:2102:25167:9795 BD+DOWNSTREAM_3'UTR 13 56 69
# >M03997:68:000000000-G35DK:1:2104:20179:21220 BD+DOWNSTREAM_3'UTR 16 178 194
# >M03997:68:000000000-G35DK:1:1102:4479:16163 BD+DOWNSTREAM_3'UTR 20 52 72
# >M03997:68:000000000-G35DK:1:1101:14223:12526 BD+DOWNSTREAM_3'UTR 21 54 75
# >M03997:68:000000000-G35DK:1:1101:21355:15381 BD+DOWNSTREAM_3'UTR 23 52 75
# >M03997:68:000000000-G35DK:1:2101:10091:11653 BD+DOWNSTREAM_3'UTR 12 25 37
# >M03997:68:000000000-G35DK:1:1101:24126:22284 BD+DOWNSTREAM_3'UTR 18 19 37
# >M03997:68:000000000-G35DK:1:1103:17422:20299 BD+DOWNSTREAM_3'UTR 22 57 79
# 17 >M03997:68:000000000-G35DK:1:2101:19043:24673 36 53
# 6 >M03997:68:000000000-G35DK:1:2101:19043:24673 93 99
# 11 >M03997:68:000000000-G35DK:1:2101:19043:24673 130 141
# 19 >M03997:68:000000000-G35DK:1:1102:11830:11286 27 46
# 6 >M03997:68:000000000-G35DK:1:1102:11830:11286 97 103
# 5 >M03997:68:000000000-G35DK:1:1102:11830:11286 125 130
# 23 >M03997:68:000000000-G35DK:1:1103:12709:28284 26 49
# 5 >M03997:68:000000000-G35DK:1:1103:12709:28284 99 104
# 7 >M03997:68:000000000-G35DK:1:1104:8014:13408 33 40
# 14 >M03997:68:000000000-G35DK:1:1104:8014:13408 41 55
# 14 >M03997:68:000000000-G35DK:1:2104:10593:22363 25 39
# 22 >M03997:68:000000000-G35DK:1:1103:14881:18679 46 68
# 6 >M03997:68:000000000-G35DK:1:1103:14881:18679 100 106
# 7 >M03997:68:000000000-G35DK:1:1103:14881:18679 111 118
# 6 >M03997:68:000000000-G35DK:1:1103:14881:18679 137 143
# 6 >M03997:68:000000000-G35DK:1:1103:14881:18679 147 153
# 14 >M03997:68:000000000-G35DK:1:1103:8918:22334 46 60
# 5 >M03997:68:000000000-G35DK:1:1103:8918:22334 110 115
# 29 >M03997:68:000000000-G35DK:1:2104:18935:7645 99 128
# 23 >M03997:68:000000000-G35DK:1:2103:27560:21888 33 56
# 6 >M03997:68:000000000-G35DK:1:2103:27560:21888 93 99
# 7 >M03997:68:000000000-G35DK:1:2103:27560:21888 103 110
# 21 >M03997:68:000000000-G35DK:1:1102:12731:24563 28 49
# 5 >M03997:68:000000000-G35DK:1:1102:12731:24563 82 87
# 6 >M03997:68:000000000-G35DK:1:1102:12731:24563 89 95
# 11 >M03997:68:000000000-G35DK:1:1102:12731:24563 117 128
# 13 >M03997:68:000000000-G35DK:1:1104:18969:10040 22 35
# 10 >M03997:68:000000000-G35DK:1:1101:17808:19674 42 52
# 16 >M03997:68:000000000-G35DK:1:1102:14877:7470 42 58
# 14 >M03997:68:000000000-G35DK:1:1102:14877:7470 138 152
# 6 >M03997:68:000000000-G35DK:1:2103:4998:16545 44 50
# 15 >M03997:68:000000000-G35DK:1:2103:4998:16545 51 66
# 27 >M03997:68:000000000-G35DK:1:2103:4998:16545 67 94
# 17 >M03997:68:000000000-G35DK:1:1102:8082:18203 26 43
# 8 >M03997:68:000000000-G35DK:1:1102:13423:3128 70 78
# 5 >M03997:68:000000000-G35DK:1:1102:13423:3128 129 134
# 6 >M03997:68:000000000-G35DK:1:1102:13423:3128 157 163
# 9 >M03997:68:000000000-G35DK:1:1102:13423:3128 169 178
# 18 >M03997:68:000000000-G35DK:1:1101:4194:9291 142 160
# 15 >M03997:68:000000000-G35DK:1:2101:3014:20692 100 115
# 13 >M03997:68:000000000-G35DK:1:1101:15574:21365 132 145
# 25 >M03997:68:000000000-G35DK:1:2101:26681:7416 148 173
# 6 >M03997:68:000000000-G35DK:1:2101:26681:7416 189 195
# 12 >M03997:68:000000000-G35DK:1:2101:16215:14035 134 146
# 20 >M03997:68:000000000-G35DK:1:2104:21406:6881 104 124
# 12 >M03997:68:000000000-G35DK:1:1101:2922:20370 158 170
# 17 >M03997:68:000000000-G35DK:1:1101:23825:18893 148 165
# 5 >M03997:68:000000000-G35DK:1:1102:25023:23000 115 120
# 18 >M03997:68:000000000-G35DK:1:2101:15877:24652 143 161
# 5 >M03997:68:000000000-G35DK:1:2101:15877:24652 244 249
# 5 >M03997:68:000000000-G35DK:1:2104:10682:16233 106 111
# 10 >M03997:68:000000000-G35DK:1:1103:18579:9554 175 185
# 15 >M03997:68:000000000-G35DK:1:2101:5995:13442 18 33
# 13 >M03997:68:000000000-G35DK:1:1102:20224:24179 151 164
# 22 >M03997:68:000000000-G35DK:1:2101:23508:4327 68 90
# 6 >M03997:68:000000000-G35DK:1:2101:23508:4327 163 169
# 5 >M03997:68:000000000-G35DK:1:2104:19387:11901 26 31
# 14 >M03997:68:000000000-G35DK:1:1102:22139:10585 27 41
# 18 >M03997:68:000000000-G35DK:1:2103:21582:16955 28 46
# 9 >M03997:68:000000000-G35DK:1:2103:21582:16955 122 131
# 15 >M03997:68:000000000-G35DK:1:1102:22185:20748 30 45
# 7 >M03997:68:000000000-G35DK:1:2101:14817:26198 25 32
# 10 >M03997:68:000000000-G35DK:1:2103:26603:14875 29 39
# 18 >M03997:68:000000000-G35DK:1:1101:5147:18901 26 44
# 5 >M03997:68:000000000-G35DK:1:1101:5147:18901 59 64
# 6 >M03997:68:000000000-G35DK:1:1101:5147:18901 87 93
# 12 >M03997:68:000000000-G35DK:1:1101:5147:18901 116 128
# 15 >M03997:68:000000000-G35DK:1:1104:15345:7958 23 38
# 12 >M03997:68:000000000-G35DK:1:1101:13500:20340 28 40
# 12 >M03997:68:000000000-G35DK:1:2101:27030:23187 91 103
# 12 >M03997:68:000000000-G35DK:1:2102:20147:21672 79 91
# 22 >M03997:68:000000000-G35DK:1:1104:22627:12138 52 74
# 6 >M03997:68:000000000-G35DK:1:1104:22627:12138 88 94
# 6 >M03997:68:000000000-G35DK:1:1104:22627:12138 148 154
# 18 >M03997:68:000000000-G35DK:1:1103:12815:13847 63 81
# 12 >M03997:68:000000000-G35DK:1:1101:25426:13768 26 38
# 17 >M03997:68:000000000-G35DK:1:2104:14853:6907 68 85
# 16 >M03997:68:000000000-G35DK:1:1102:11704:9378 79 95
# 17 >M03997:68:000000000-G35DK:1:1101:21664:14721 89 106
# 15 >M03997:68:000000000-G35DK:1:2102:17419:4089 21 36
# 9 >M03997:68:000000000-G35DK:1:2102:17419:4089 115 124
# 7 >M03997:68:000000000-G35DK:1:2102:17419:4089 241 248
# 16 >M03997:68:000000000-G35DK:1:2103:18809:10748 23 39
# 35 >M03997:68:000000000-G35DK:1:1104:24077:25476 26 61
# 7 >M03997:68:000000000-G35DK:1:1104:24077:25476 104 111
# 11 >M03997:68:000000000-G35DK:1:2101:19208:12409 194 205
# 5 >M03997:68:000000000-G35DK:1:2101:19208:12409 210 215
# 20 >M03997:68:000000000-G35DK:1:1102:28403:18305 127 147
# 22 >M03997:68:000000000-G35DK:1:1104:26710:20671 20 42
# 9 >M03997:68:000000000-G35DK:1:1104:26710:20671 85 94
# 9 >M03997:68:000000000-G35DK:1:1104:26710:20671 115 124
# 13 >M03997:68:000000000-G35DK:1:2102:9353:17927 130 143
# 9 >M03997:68:000000000-G35DK:1:2102:9353:17927 170 179
# 6 >M03997:68:000000000-G35DK:1:2102:9353:17927 182 188
# 28 >M03997:68:000000000-G35DK:1:2102:9807:14086 26 54
# 7 >M03997:68:000000000-G35DK:1:2102:9807:14086 99 106
# 6 >M03997:68:000000000-G35DK:1:2102:9807:14086 131 137
# 6 >M03997:68:000000000-G35DK:1:2102:9807:14086 165 171
# 8 >M03997:68:000000000-G35DK:1:2102:9807:14086 184 192
# 5 >M03997:68:000000000-G35DK:1:2102:9807:14086 193 198
# 5 >M03997:68:000000000-G35DK:1:2102:9807:14086 243 248
# 21 >M03997:68:000000000-G35DK:1:2102:17385:19365 30 51
# 10 >M03997:68:000000000-G35DK:1:2102:17385:19365 98 108
# 13 >M03997:68:000000000-G35DK:1:2102:17385:19365 130 143
# 8 >M03997:68:000000000-G35DK:1:2102:17385:19365 203 211
# 25 >M03997:68:000000000-G35DK:1:1104:19844:4564 36 61
# 13 >M03997:68:000000000-G35DK:1:1104:19844:4564 136 149
# 5 >M03997:68:000000000-G35DK:1:1104:19844:4564 150 155
# 10 >M03997:68:000000000-G35DK:1:1104:19844:4564 219 229
# 7 >M03997:68:000000000-G35DK:1:1104:19844:4564 239 246
# 11 >M03997:68:000000000-G35DK:1:1104:19844:4564 280 291
# 5 >M03997:68:000000000-G35DK:1:1103:27803:14089 32 37
# 23 >M03997:68:000000000-G35DK:1:1103:27803:14089 52 75
# 7 >M03997:68:000000000-G35DK:1:1103:27803:14089 260 267
# 14 >M03997:68:000000000-G35DK:1:1102:25175:19691 26 40
# 20 >M03997:68:000000000-G35DK:1:1101:17914:23339 19 39
# 10 >M03997:68:000000000-G35DK:1:1101:17914:23339 117 127
# 22 >M03997:68:000000000-G35DK:1:2104:9794:7584 26 48
# 7 >M03997:68:000000000-G35DK:1:2104:9794:7584 89 96
# 6 >M03997:68:000000000-G35DK:1:2104:9794:7584 97 103
# 13 >M03997:68:000000000-G35DK:1:2104:9794:7584 125 138
# 5 >M03997:68:000000000-G35DK:1:2104:9794:7584 207 212
# 13 >M03997:68:000000000-G35DK:1:1101:17405:27376 32 45
# 22 >M03997:68:000000000-G35DK:1:1102:23057:14367 26 48
# 8 >M03997:68:000000000-G35DK:1:1102:23057:14367 67 75
# 7 >M03997:68:000000000-G35DK:1:1102:23057:14367 87 94
# 9 >M03997:68:000000000-G35DK:1:1102:23057:14367 95 104
# 17 >M03997:68:000000000-G35DK:1:1102:23057:14367 124 141
# 7 >M03997:68:000000000-G35DK:1:1102:23057:14367 238 245
# 20 >M03997:68:000000000-G35DK:1:2101:18181:2225 98 118
# 10 >M03997:68:000000000-G35DK:1:2101:18181:2225 153 163
# 6 >M03997:68:000000000-G35DK:1:2101:18181:2225 185 191
# 10 >M03997:68:000000000-G35DK:1:2101:18181:2225 192 202
# 17 >M03997:68:000000000-G35DK:1:2104:27871:16617 88 105
# 9 >M03997:68:000000000-G35DK:1:2103:13603:26688 144 153
# 49 >M03997:68:000000000-G35DK:1:1102:26591:10477 57 106
# 6 >M03997:68:000000000-G35DK:1:1102:26591:10477 120 126
# 5 >M03997:68:000000000-G35DK:1:1102:26591:10477 142 147
# 6 >M03997:68:000000000-G35DK:1:1102:26591:10477 149 155
# 7 >M03997:68:000000000-G35DK:1:1102:26591:10477 291 298
# 5 >M03997:68:000000000-G35DK:1:1101:26001:18420 148 153
# 12 >M03997:68:000000000-G35DK:1:1101:26001:18420 176 188
# 17 >M03997:68:000000000-G35DK:1:1101:26546:8841 121 138
# 5 >M03997:68:000000000-G35DK:1:1101:26546:8841 215 220
# 17 >M03997:68:000000000-G35DK:1:1103:22275:16304 78 95
# 19 >M03997:68:000000000-G35DK:1:1101:6208:25546 63 82
# 5 >M03997:68:000000000-G35DK:1:1101:6208:25546 92 97
# 10 >M03997:68:000000000-G35DK:1:1101:6208:25546 147 157
# 11 >M03997:68:000000000-G35DK:1:1101:6208:25546 165 176
# 14 >M03997:68:000000000-G35DK:1:2102:23507:5453 105 119
# 6 >M03997:68:000000000-G35DK:1:2103:11902:14952 103 109
# 22 >M03997:68:000000000-G35DK:1:1103:21332:20091 67 89
# 5 >M03997:68:000000000-G35DK:1:1103:21332:20091 138 143
# 9 >M03997:68:000000000-G35DK:1:1103:21332:20091 166 175
# 10 >M03997:68:000000000-G35DK:1:1103:21332:20091 184 194
# 21 >M03997:68:000000000-G35DK:1:1102:25082:20440 75 96
# 5 >M03997:68:000000000-G35DK:1:1102:25082:20440 140 145
# 12 >M03997:68:000000000-G35DK:1:1102:25082:20440 168 180
# 18 >M03997:68:000000000-G35DK:1:1102:15544:10457 63 81
# 19 >M03997:68:000000000-G35DK:1:2103:18212:25552 33 52
# 6 >M03997:68:000000000-G35DK:1:2103:18212:25552 92 98
# 9 >M03997:68:000000000-G35DK:1:2103:18212:25552 100 109
# 13 >M03997:68:000000000-G35DK:1:2103:18212:25552 128 141
# 6 >M03997:68:000000000-G35DK:1:2103:18212:25552 150 156
# 5 >M03997:68:000000000-G35DK:1:2103:18212:25552 205 210
# 6 >M03997:68:000000000-G35DK:1:1101:22893:23574 33 39
# 12 >M03997:68:000000000-G35DK:1:1101:22893:23574 40 52
# 15 >M03997:68:000000000-G35DK:1:2104:12914:21494 103 118
# 13 >M03997:68:000000000-G35DK:1:2104:12914:21494 190 203
# 24 >M03997:68:000000000-G35DK:1:2104:22614:5511 38 62
# 5 >M03997:68:000000000-G35DK:1:1101:13733:21025 73 78
# 25 >M03997:68:000000000-G35DK:1:1104:11157:11264 79 104
# 11 >M03997:68:000000000-G35DK:1:1104:11157:11264 138 149
# 5 >M03997:68:000000000-G35DK:1:1104:11157:11264 175 180
# 25 >M03997:68:000000000-G35DK:1:1101:10859:20693 125 150
# 22 >M03997:68:000000000-G35DK:1:1103:22856:7778 63 85
# 5 >M03997:68:000000000-G35DK:1:1103:22856:7778 136 141
# 11 >M03997:68:000000000-G35DK:1:1103:22856:7778 163 174
# 6 >M03997:68:000000000-G35DK:1:1103:22856:7778 293 299
# 15 >M03997:68:000000000-G35DK:1:1101:25055:13448 121 136
# 17 >M03997:68:000000000-G35DK:1:2101:11698:20951 62 79
# 12 >M03997:68:000000000-G35DK:1:2101:11721:12872 132 144
# 20 >M03997:68:000000000-G35DK:1:1104:18717:22333 103 123
# 14 >M03997:68:000000000-G35DK:1:1103:8363:11858 74 88
# 13 >M03997:68:000000000-G35DK:1:2101:8407:23573 98 111
# 15 >M03997:68:000000000-G35DK:1:1101:6016:11810 28 43
# 6 >M03997:68:000000000-G35DK:1:1101:6016:11810 121 127
# 15 >M03997:68:000000000-G35DK:1:2102:20791:8313 109 124
# 7 >M03997:68:000000000-G35DK:1:2102:20791:8313 204 211
# 19 >M03997:68:000000000-G35DK:1:1101:25467:14593 80 99
# 5 >M03997:68:000000000-G35DK:1:1101:25467:14593 149 154
# 11 >M03997:68:000000000-G35DK:1:1101:25467:14593 177 188
# 6 >M03997:68:000000000-G35DK:1:1101:25467:14593 195 201
# 17 >M03997:68:000000000-G35DK:1:2103:10306:4367 68 85
# 12 >M03997:68:000000000-G35DK:1:2103:10306:4367 173 185
# 17 >M03997:68:000000000-G35DK:1:2104:9118:13431 72 89
# 8 >M03997:68:000000000-G35DK:1:2104:9118:13431 170 178
# 26 >M03997:68:000000000-G35DK:1:2101:11512:3024 67 93
# 6 >M03997:68:000000000-G35DK:1:2101:11512:3024 173 179
# 16 >M03997:68:000000000-G35DK:1:1103:15695:7962 57 73
# 13 >M03997:68:000000000-G35DK:1:1103:15695:7962 139 152
# 5 >M03997:68:000000000-G35DK:1:1103:15695:7962 153 158
# 11 >M03997:68:000000000-G35DK:1:2102:15270:7183 85 96
# 5 >M03997:68:000000000-G35DK:1:1101:12123:25562 73 78
# 16 >M03997:68:000000000-G35DK:1:1101:6817:10866 57 73
# 33 >M03997:68:000000000-G35DK:1:1104:17544:13177 88 121
# 9 >M03997:68:000000000-G35DK:1:1104:17544:13177 136 145
# 6 >M03997:68:000000000-G35DK:1:1104:17544:13177 152 158
# 14 >M03997:68:000000000-G35DK:1:1104:20193:24822 90 104
# 16 >M03997:68:000000000-G35DK:1:1102:22849:20903 67 83
# 6 >M03997:68:000000000-G35DK:1:1102:22849:20903 166 172
# 19 >M03997:68:000000000-G35DK:1:1101:4516:12146 72 91
# 9 >M03997:68:000000000-G35DK:1:1101:4516:12146 176 185
# 17 >M03997:68:000000000-G35DK:1:1103:3874:17211 109 126
# 14 >M03997:68:000000000-G35DK:1:1102:16365:14360 109 123
# 13 >M03997:68:000000000-G35DK:1:2102:25167:9795 56 69
# 6 >M03997:68:000000000-G35DK:1:2104:20179:21220 93 99
# 5 >M03997:68:000000000-G35DK:1:2104:20179:21220 140 145
# 12 >M03997:68:000000000-G35DK:1:2104:20179:21220 177 189
# 20 >M03997:68:000000000-G35DK:1:1102:4479:16163 52 72
# 7 >M03997:68:000000000-G35DK:1:1102:4479:16163 94 101
# 5 >M03997:68:000000000-G35DK:1:1102:4479:16163 115 120
# 5 >M03997:68:000000000-G35DK:1:1102:4479:16163 123 128
# 5 >M03997:68:000000000-G35DK:1:1102:4479:16163 156 161
# 21 >M03997:68:000000000-G35DK:1:1101:14223:12526 54 75
# 7 >M03997:68:000000000-G35DK:1:1101:14223:12526 97 104
# 6 >M03997:68:000000000-G35DK:1:1101:14223:12526 116 122
# 11 >M03997:68:000000000-G35DK:1:1101:14223:12526 152 163
# 6 >M03997:68:000000000-G35DK:1:1101:14223:12526 164 170
# 23 >M03997:68:000000000-G35DK:1:1101:21355:15381 52 75
# 12 >M03997:68:000000000-G35DK:1:2101:10091:11653 25 37
# 18 >M03997:68:000000000-G35DK:1:1101:24126:22284 19 37
# 22 >M03997:68:000000000-G35DK:1:1103:17422:20299 57 79
# 5 >M03997:68:000000000-G35DK:1:1103:17422:20299 103 108
